# %% [markdown]
# # **● Problem Statement:**

# %% [markdown]
# Over recent years, as the popularity of mobile phone devices has increased, Short
# Message Service (SMS) has grown into a multi-billion dollar industry. At the same time,
# reduction in the cost of messaging services has resulted in growth in unsolicited
# commercial advertisements (spams) being sent to mobile phones. Due to Spam SMS,
# Mobile service providers suffer from some sort of financial problems as well as it reduces
# calling time for users. Unfortunately, if the user accesses such Spam SMS they may face
# the problem of virus or malware. When SMS arrives at mobile it will disturb mobile user
# privacy and concentration. It may lead to frustration for the user. So Spam SMS is one of
# the major issues in the wireless communication world and it grows day by day.

# %% [markdown]
# # **● Import required library**

# %%
import csv,io
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
nltk.download('stopwords')  
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv(io.FileIO('/content/spam.csv'), encoding = "ISO-8859-1")

# %% [markdown]
# # **● Read dataset and do pre-processing**

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2

# %% [markdown]
# # **● Create Model**

# %%
articles = []
labels = []

with open("spam.csv", 'r', encoding = "ISO-8859-1") as dataset:
    reader = csv.reader(dataset, delimiter=',')
    next(reader)
    for row in reader:
        labels.append(row[0])
        article = row[1]
        for word in STOPWORDS:
            token = ' ' + word + ' '
            article = article.replace(token, ' ')
        articles.append(article)
len=int(5572 * 0.8)
train_articles = articles[0: len]
train_labels = labels[0: len]

validation_articles = articles[len:]
validation_labels = labels[len:]

# %%
np.unique(validation_labels)
# Out:
# array(['ham', 'spam'], dtype='<U4')

# %%
validation_articles
# Out:
# ['Die... I accidentally deleted e msg suppose 2 put e sim archive. Haiz... I sad...',
#  'Welcome UK-mobile-date msg FREE giving free calling 08719839835. Future mgs billed 150p daily. To cancel send \\go stop\\" 89123"',
#  'This wishing great day. Moji told offer always speechless. You offer easily go great lengths behalf stunning. My exam next friday. After keep touch more. Sorry.',
#  'Thanks reply today. When ur visa coming in. And r u still buying gucci bags. My sister things easy, uncle john also bills really need think make money. Later sha.',
#  "Sorry I flaked last night, shit's seriously goin roommate, tonight?",
#  "He said look pretty wif long hair wat. But thk he's cutting quite short 4 leh.",
#  'Ranjith cal drpd Deeraj deepak 5min hold',
#  '\\CHEERS FOR CALLIN BABE.SOZI CULDNT TALKBUT I WANNATELL U DETAILS LATER WENWECAN CHAT PROPERLY X\\""',
#  'Hey u still gym?',
#  "She said,'' u mind I go bedroom minute ? '' ''OK'', I sed sexy mood. She came 5 minuts latr wid cake...n My Wife,",
#  'Much better thanks lol',
#  'Nothing, smsing u n xy lor. Sorry lor da guys neva c u person sort know u lor. So u wan 2 meet xy ask 2 bring u along 4 next meeting.',
#  "Lemme know I swing pick up, I'm free basically time 1 semester",
#  'Wa... U efficient... Gee... Thanx...',
#  '3. You received mobile content. Enjoy',
#  'S able sleep.',
#  'Want explicit SEX 30 secs? Ring 02073162414 now! Costs 20p/min',
#  'We meet soon princess! Ttyl!',
#  "I'll pick 5.15pm go taunton still want come.",
#  'Oh :-)only 4 outside players allowed play know',
#  'I anything lor.',
#  'Erutupalam thandiyachu',
#  "Y cant u try new invention fly..i'm joking.,",
#  'No..its ful song lyrics..',
#  "What u reckon need 2 arrange transport u can't it, thanks",
#  'True lov n care wil nevr go unrecognized. though somone often makes mistakes valuing it. definitly undrstnd start missing it.',
#  'Shopping? Eh ger toking abt syd leh...Haha',
#  'What standing.',
#  'have * good weekend.',
#  'Miss call miss call khelate kintu opponenter miss call dhorte lage. Thats rule. One great phone receiving quality wins.',
#  'Call get chance plz &lt;3',
#  'The new deus ex game comin early next yr',
#  'My computer fried essential part keep spares fucking idiot roommates looovvve leaving thing running full  &lt;#&gt; /7',
#  "My friend, studying warwick, we've planned go shopping concert tmw, may canceled, havn't seen  ages, yeah get together sometime!",
#  'Probably couple hours tops',
#  "LOL .. *grins* .. I'm babe, thanks thinking me!",
#  'Man bus so slow. I think gonna get me',
#  'Hope text meets smiling. If let text give reason smile. Have beautiful day.',
#  'In case wake wondering I am, I forgot I take care something grandma today, done parade',
#  'Ok',
#  'Latest Nokia Mobile iPOD MP3 Player +å£400 proze GUARANTEED! Reply with: WIN 83355 now! Norcorp Ltd.å£1,50/Mtmsgrcvd18+',
#  'SMS SERVICES. inclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe STOP, extra charge. help 08702840625.COMUK. 220-CM2 9AE',
#  'Nvm take ur time.',
#  "So wat's da decision?",
#  'Wot u 2 bitch?',
#  'Stupid.its possible',
#  "She told hr want posting chennai:)because i'm working here:)",
#  'Mobile Club: Choose top quality items mobile. 7cfca1a',
#  'When guys leaving?',
#  'He neva grumble sad lor... Hee... Buy tmr lor aft lunch. But still meetin 4 lunch tmr not. Neva hear fr lei. ÌÏ got lot work ar?',
#  'Not able anything.',
#  'ÌÏ takin linear algebra today?',
#  'This weekend fine (an excuse much decorating)',
#  'Sorry I missed babe. I late slept in. I hope enjoy driving lesson, boytoy. I miss ... *teasing kiss*',
#  'Now project pa. After come.',
#  'Money wining number 946 wot do next',
#  'Sure, whenever show fuck &gt;:(',
#  'That random saw old roomate campus. He graduated',
#  'Congrats! 2 mobile 3G Videophones R yours. call 09061744553 now! videochat wid ur mates, play java games, Dload polyH music, noline rentl. bx420. ip4. 5we. 150pm',
#  'Men always needs beautiful, intelligent, caring, loving, adjustable, cooperative wife. But law allows one wife....',
#  'That sucks. So got planned yo valentine? I yo valentine I?',
#  'Just got part Nottingham - 3 hrs 63miles. Good thing love man much, 40mph. Hey ho',
#  'What think one saying clearly. Ok leave need ask her. I go come not',
#  'Hi good mornin.. Thanku wish u same..',
#  'DO U WANT 2 MEET UP 2MORRO',
#  'Actually I decided I hungry I left yet :V',
#  "I've sent Ì_ part..",
#  'Cos shopping wif darren jus n called 2 ask wat present wan lor. Then started guessing wif n finally guessed darren lor.',
#  "I want cock! My hubby's away, I need real man 2 satisfy me. Txt WIFE 89938 strings action. (Txt STOP 2 end, txt rec å£1.50ea. OTBox 731 LA1 7WS. )",
#  'Understand. loss gain :) work? School?',
#  'HOW ARE U? I HAVE MISSED U! I HAVENT BEEN UP 2 MUCH A BIT BORED WITH THE HOLIDAY WANT 2 GO BAK 2 COLLEGE! SAD ISNT IT?xx',
#  'Hiya, probably coming home * weekend next',
#  "Don't forget though I love .... And I walk beside you. Watching keeping heart warm.",
#  'I wish things different. I wonder able show much value you. Pls continue brisk walks drugs without askin please find things laugh about. I love dearly.',
#  'Ok days. So making dinner tonite? Am I invited?',
#  'Gr8 new service - live sex video chat mob - see sexiest dirtiest girls live ur phone - 4 details text horny 89070 cancel send STOP 89070',
#  'I money 4 steve mate! !',
#  'IM LATE TELLMISS IM ON MY WAY',
#  'Never blame day ur life. Good days give u happiness. Bad days give u experience. Both essential life! All Gods blessings! good morning.:',
#  'Normally use drink water daily:)',
#  'Dare ask... Any luck sorting car?',
#  "Party's place usf, charge (but contribute way greatly appreciated) yeah, got room one more",
#  'Urgh, coach hot, smells chip fat! Thanks again, especially duvet (not predictive text word).',
#  "Hiya. How last night? I've naughty bought clothes little ... Ready shopping tho! What kind time wanna meet?",
#  'FreeMsg Hi baby wow got new cam moby. Wanna C hot pic? Fancy chat?Im w8in 4uTxt / rply CHAT 82242 Hlp 08712317606 Msg150p 2rcv',
#  "I've trying reach without success",
#  'when derek done class?',
#  'Never lei... I v lazy... Got wat? Dat day Ì_ send da url cant work one...',
#  'Never try alone take weight tear comes ur heart falls ur eyes... Always remember STUPID FRIEND share... BSLVYL',
#  'Hey mate. Spoke mag people. We\x89Û÷re on.  deliver end month. Deliver 24th sept. Talk later. ',
#  'Hope good week. Just checking in',
#  'Haha, friend tyler literally asked could get dubsack',
#  '\\Hey! u fancy meetin 4 cha åÐ hav lil beverage me. txt ring meet l8r. quite tired got 3 v.pist ;) love Pete x x x\\""',
#  'Great. Have safe trip. Dont panic surrender all.',
#  '\\SYMPTOMS\\" U love: \\"1.U like listening songs 2.U get stopped u see name beloved 3.U get angry your"',
#  'Sun ah... Thk mayb dun anythin on... Thk book e lesson... E pilates orchard mrt u noe hor...  ',
#  'Try something dear. You read something exams',
#  '7 wonders My WORLD 7th You 6th Ur style 5th Ur smile 4th Ur Personality 3rd Ur Nature 2nd Ur SMS 1st \\Ur Lovely Friendship\\"... good morning dear"',
#  'Gettin rdy ship comp',
#  'I hospital da. . I return home evening',
#  'PISS IS TALKING IS SOMEONE THAT REALISE U THAT POINT THIS AT IS IT.(NOW READ IT BACKWARDS)',
#  'Think + da. You wil do.',
#  "I'm awake oh. What's up.",
#  'Good afternoon boytoy. How goes walking day ? Did get police abstract? Are still about? I wake miss babe',
#  'How much u trying get?',
#  "Come around  &lt;DECIMAL&gt; pm vikky..i'm otside nw, il come tht time",
#  'Tell address is',
#  "Honeybee Said: *I'm Sweetest World* God Laughed &amp; Said: *Wait,U Havnt Met Person Reading This Msg* MORAL: Even GOD Can Crack Jokes! GM+GN+GE+GN:)",
#  'Should buy blackberry bold 2 torch. Should buy new used. Let know. Plus saying buy  &lt;#&gt; g wifi ipad. And saying the  &lt;#&gt; g?',
#  'But together thinkin him',
#  'hiya hows going sunny africa? hope u r avin good time. give big old silver back big kiss me.',
#  'At WHAT TIME come tomorrow',
#  'Wanna laugh? Try CHIT-CHAT mobile now! Logon txting word: CHAT send No: 8883 CM PO Box 4217 London W1A 6ZF 16+ 118p/msg rcvd',
#  '\\CHA QUITEAMUZING THATåÕSCOOL BABE',
#  'Omg u know I ate?',
#  '\\URGENT! This 2nd attempt contact U!U WON å£1000CALL 09071512432 b4 300603t&csBCM4235WC1N3XX.callcost150ppmmobilesvary. maxå£7. 50\\""',
#  ':( here....',
#  'Not directly behind... Abt 4 rows behind Ì_...',
#  'Congratulations ur awarded 500 CD vouchers 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC 87066',
#  'Had contract mobile 11 Mnths? Latest Motorola, Nokia etc. FREE! Double Mins & Text Orange tariffs. TEXT YES callback, remove records',
#  'Urgent! call 09066350750 landline. Your complimentary 4* Ibiza Holiday 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18+',
#  'No plans yet. What ?',
#  'Hi ....My engagement fixd  &lt;#&gt; th next month. I know really shocking bt....hmm njan vilikkam....t ws al sudn;-(.',
#  'Not course. Only maths one day one chapter one month finish.',
#  'Wow think common. I take back ur freak! Unless u chop off:-)',
#  "For ur chance win å£250 wkly shopping spree TXT: SHOP 80878. T's&C's www.txt-2-shop.com custcare 08715705022, 1x150p/wk",
#  'Noooooooo please. Last thing I need stress. For life fair.',
#  'U Secret Admirer looking 2 make contact U-find R*reveal thinks UR special-call 09065171142-stopsms-08718727870150ppm',
#  'Mila, age23, blonde, new UK. I look sex UK guys. u like fun me. Text MTALK 69866.18 . 30pp/txt 1st 5free. å£1.50 increments. Help08718728876',
#  "I'll see I swing bit, got things take care firsg",
#  "I wanted wish Happy New Year I wanted talk legal advice Gary I split person. I'll make trip Ptbo that. I hope everything good babe I love ya :)",
#  'Have finished work yet something?',
#  'Tomorrow going theatre. . . So come wherever u call me. . . Tell come tomorrow',
#  'Well done ENGLAND! Get official poly ringtone colour flag yer mobile! text TONE FLAG 84199 NOW! Opt-out txt ENG STOP. Box39822 W111WX å£1.50',
#  'Right wasnt phoned someone number like yours!',
#  "It's ok wun b angry. Msg u aft come home tonight.",
#  'I good time too. Its nice something bit different weekends change. See ya soon',
#  'Yo sorry shower sup',
#  "Carlos I pick him, I'll swing usf little bit",
#  'Full heat pa:-) applyed oil pa.',
#  "I'm stuck da middle da row da right hand side da lt... ",
#  'Have laid airtel line rest?',
#  'Hi u decide wot 2 get 4 bday ill prob jus get voucher frm virgin sumfing ',
#  'FreeMsg: Txt: CALL No: 86888 & claim reward 3 hours talk time use phone now! Subscribe6GBP/mnth inc 3hrs 16 stop?txtStop',
#  '\\Hey j! r u feeling better',
#  'And I plan staying night I prolly back til late',
#  'THANX 4 PUTTIN DA FONE DOWN ON ME!!',
#  "I need 8th I'm campus atm, could I pick hour two?",
#  'Oh... Haha... Den shld went today too... Gee, nvm la... Kaiez, dun mind goin jazz oso... Scared hiphop open cant catch up... ',
#  'Been running managed 5 minutes needed oxygen! Might resort roller option!',
#  'We live next  &lt;#&gt; mins',
#  'Y de asking like this.',
#  'Just glad talking you.',
#  'Wat time Ì_ finish?',
#  'Sorry da. I gone mad many pending works do.',
#  'How much got cleaning',
#  'hows favourite person today? r u workin hard? sleep last nite nearly rang u 4.30',
#  'Sunshine Quiz! Win super Sony DVD recorder canname capital Australia? Text MQUIZ 82277. B',
#  'ÌÏ called dad oredi...',
#  'Good. think could send pix? I would love see top bottom...',
#  "Nvm... I'm going wear sport shoes anyway... I'm going late leh.",
#  "Sorry, I'll call later In meeting.",
#  'THIS IS A LONG FUCKIN SHOWR',
#  'Received, understood n acted upon!',
#  'They finally came fix ceiling.',
#  'U need presnts always bcz U cant mis love. \\jeevithathile irulinae neekunna prakasamanu sneham\\" prakasam ennal prabha \'That mns prabha is\'LOVE\' Got it. Dont mis me...."',
#  'Jus finish blowing hair. U finish dinner already?',
#  "I'm bus. Love you",
#  'Lol ... I knew .... I saw dollar store',
#  'Please call customer service representative 0800 169 6031 10am-9pm WON guaranteed å£1000 cash å£5000 prize!',
#  'Todays Voda numbers ending 7634 selected receive å£350 reward. If match please call 08712300220 quoting claim code 7684 standard rates apply.',
#  'Only saturday sunday holiday difficult:)',
#  'Everybody fun evening. Miss you.',
#  'Got hella gas money, want go grand nature adventure galileo little bit?',
#  "I'm meeting, call later at",
#  'Oh wow thats gay. Will firmware update help',
#  'These do. Have move morphine',
#  'How come din c Ì_... Yup cut hair...',
#  'K k pa Had lunch aha.',
#  'Oh ho. Is first time u use type words',
#  'Captain vijaykanth comedy captain tv..he drunken :)',
#  "Of course. I guess god's got hold right now.",
#  'Do hide anythiing keeping distance me',
#  'Havent.',
#  'You ripped off! Get mobile content www.clubmoby.com call 08717509990 poly/true/Pix/Ringtones/Games six downloads 3',
#  'Sorry din lock keypad.',
#  'Did u got persons story',
#  'Are planning come chennai?',
#  'We tried contact reply offer Video Phone 750 anytime network mins Half Price Line Rental Camcorder Reply call 08000930705',
#  'God created gap btwn ur fingers dat sum1 vry special fill gaps holding ur hands.. Now plz dont ask created much gap legs !!!',
#  'We okay. Going sleep now. Later',
#  'Please protect e-threats. SIB never asks sensitive information like Passwords,ATM/SMS PIN thru email. Never share password anybody.',
#  'Finally happened..! Aftr decades..! BEER cheaper PETROL! The goverment expects us \\DRINK\\". . . But \\"DRIVE \\""',
#  'A å£400 XMAS REWARD IS WAITING FOR YOU! Our computer randomly picked loyal mobile customers receive å£400 reward. Just call 09066380611 ',
#  'Where r e meeting tmr?',
#  'Lol yes. But add spice day.',
#  'Hope great day.',
#  'Our Prasanth ettans mother passed away last night. Just pray family.',
#  "K, I'll work something out",
#  'PRIVATE! Your 2003 Account Statement shows 800 un-redeemed S. I. M. points. Call 08718738002 Identifier Code: 48922 Expires 21/11/04',
#  'This message great Doctor India:-): 1) Do drink APPY FIZZ. It contains Cancer causing age',
#  'I cant pick phone right now. Pls send message',
#  'You call tell infront them. Call now.',
#  'Ok prob...',
#  'Ladies first genus second k .',
#  'No. Yes please. Been swimming?',
#  'Mum going robinson already.',
#  'Ok set let u noe e details later...',
#  'Not..tel software name..',
#  'I send print  outs da.',
#  'IM REALY SOZ IMAT MY MUMS 2NITE WHAT ABOUT 2MORO ',
#  'When I born, GOD said, \\Oh No! Another IDIOT\\". When born',
#  'I didnt get ur full msg..sometext missing, send again',
#  "Probably not, I'm almost gas I get cash tomorrow",
#  'Customer service announcement. We recently tried make delivery unable so, please call 07099833605 re-schedule. Ref:9280114',
#  "I forgot 2 ask Ì_ smth.. There's card da present lei... How? ÌÏ want 2 write smth sign it?",
#  "I'm leaving house now.",
#  'Hi babe Chloe, r u? I smashed saturday night, great! How weekend? U missing me? SP visionsms.com Text stop stop 150p/text',
#  'ÌÏ ready call me...',
#  'Wewa 130. Iriver 255. All 128 mb.',
#  "It good thing I'm getting connection bw",
#  'Sry da..jst nw came home..',
#  "That's cool he'll night, lemme know around",
#  'Are staying town ?',
#  'Haha yeah, 2 oz kind shitload',
#  'Ok u take shopping u get paid =D',
#  'My life Means lot me, Not I love life, But I love people life, The world calls friends, I call World:-).. Ge:-)..',
#  "Alright we'll bring you, see like  &lt;#&gt;  mins",
#  'But pls dont play others life.',
#  'Eatin lunch...',
#  'Hmmm.but give one day..',
#  "Didn't try, g I decided head out",
#  'Ok prob',
#  'Surly ill give you:-) coming review.',
#  "By march ending, ready. But call sure. The problem capital never complete. How far you. How's work ladies",
#  'Tessy..pls favor. Pls convey birthday wishes Nimya..pls dnt forget it. Today birthday Shijas',
#  'Pls give food preferably pap slowly loads sugar. You take hour give it. And water. Very slowly.',
#  'URGENT! Your Mobile No 07808726822 awarded å£2,000 Bonus Caller Prize 02/09/03! This 2nd attempt contact YOU! Call 0871-872-9758 BOX95QU',
#  'A guy gets used dumb realize it.',
#  'Okey dokey, i\x89Û÷ll bit sorting stuff out.',
#  'Don da:)whats plan?',
#  'Yes fine ',
#  'WIN: We winner! Mr. T. Foley iPod! More exciting prizes soon, keep eye ur mobile visit www.win-82050.co.uk',
#  'I liked new mobile',
#  'Anytime...',
#  'Mmmmmmm *snuggles you* ...*deep contented sigh* ... *whispers* ... I fucking love much I barely stand ...',
#  'Yar say got error.',
#  'Hey anyway :-)',
#  "Wow healthy. Old airport rd lor. Cant thk anything else. But i'll b bathing dog later.",
#  'Wif family booking tour package.',
#  'Did say bold, torch later. Or one torch 2bold?',
#  'Haha awesome, I might need take that, doin tonight?',
#  'Ya knw u vl giv..its ok thanks kano..anyway enjoy wit ur family wit 1st salary..:-);-)',
#  'Huh slow tot u reach long ago liao... U 2 days 4 leh...',
#  'Thats cool princess! I cover face hot sticky cum :)',
#  'Big brother\x89Û÷s really scraped barrel shower social misfits',
#  'Oops thk dun haf enuff... I go check tell Ì_..',
#  'S:)8 min go lunch:)',
#  'Hey. What happened? U switch ur cell whole day. This isnt good. Now u care, give call tomorrow.',
#  "K do, addie &amp; I art I'll get home",
#  'My uncles Atlanta. Wish guys great semester.',
#  "Aiyo... Her lesson early... I'm still sleepin, haha... Okie, u go home liao den confirm w lor...",
#  'Forgot tell Ì_ smth.. Can Ì_ like number sections clearer..',
#  'Yup. Anything lor, u dun wan ok...',
#  "I'm home, love ... If still awake ... *loving kiss*",
#  'HELLO PEACH! MY CAKE TASTS LUSH!',
#  'FREE GAME. Get Rayman Golf 4 FREE O2 Games Arcade. 1st get UR games settings. Reply POST, save & activ8. Press 0 key Arcade. Termsapply',
#  "There'll minor shindig place later tonight, interested?",
#  'Jason says cool pick place like hour',
#  'Had mobile 10 mths? Update latest Camera/Video phones FREE. KEEP UR SAME NUMBER, Get extra free mins/texts. Text YES call',
#  'I (Career Tel) added u contact INDYAROCKS.COM send FREE SMS. To remove phonebook - sms NO  &lt;#&gt;',
#  "I've reached already.",
#  'I dont know ask brother. Nothing problem thing that. Just told .',
#  'K:)eng rocking ashes:)',
#  "Wat time r Ì_ going xin's hostel?",
#  'Good Morning Dear Shijutta........... Have great &amp; successful day.',
#  'Buy Space Invaders 4 chance 2 win orig Arcade Game console. Press 0 Games Arcade (std WAP charge) See o2.co.uk/games 4 Terms + settings. No purchase',
#  'Oh k:)after placement ah?',
#  'Not possession, especially first offense',
#  'Nt driving even many reasons called BBD..thts chikku, hw abt dvg cold..heard tht vinobanagar violence hw condition..and hw ru ? Any problem?',
#  'I bought test yesterday. Its something lets know exact day u ovulate.when get 2u 2 3wks. But pls pls dont fret. I know u r worried. Pls relax. Also anything ur past history u need tell me?',
#  'We pizza u want',
#  'I keep seeing weird shit bein \\woah\\" realising actually reasonable I\'m \\"oh\\""',
#  'Many happy returns day. I wish happy birthday.',
#  'Ya nice. . .be ready thursday',
#  'I hospital da. . I return home evening',
#  '\\Thinking u ;) x\\""',
#  'Camera - You awarded SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.',
#  'Orh tot u say still dun believe.',
#  'When put + sign, choose number pin show. Right?',
#  'The beauty life next second.. hides thousands secrets. I wish every second wonderful ur life...!! gud n8',
#  'Thanx u darlin!im cool thanx. A bday drinks 2 nite. 2morrow off! Take care c u soon.xxx',
#  'If still up, maybe leave credit card I get gas I get back like told to',
#  'Your weekly Cool-Mob tones ready download !This weeks new Tones include: 1) Crazy Frog-AXEL F>>> 2) Akon-Lonely>>> 3) Black Eyed-Dont P >>>More info n',
#  'Well boy I glad G wasted night applebees nothing',
#  'Cashbin.co.uk (Get lots cash weekend!) www.cashbin.co.uk Dear Welcome weekend We got biggest best EVER cash give away!! These..',
#  'Ok lor... Or u wan go look 4 u?',
#  "U wan 2 haf lunch i'm da canteen now.",
#  "Don't make life stressfull.. Always find time Laugh.. It may add years Life! But surely adds life ur years!! Gud ni8..swt dreams..",
#  "hey, looks like I wrong one kappa guys numbers still phone, want I text see he's around",
#  'URGENT! Your Mobile number awarded å£2000 prize GUARANTEED. Call 09061790121 land line. Claim 3030. Valid 12hrs 150ppm',
#  'Thanks 4 continued support Your question week enter u in2 draw 4 å£100 cash. Name NEW US President? txt ans 80082',
#  "I'm home. Doc gave pain meds says everything fine.",
#  "It's Ì© $140 ard...Ìä rest ard $180 least...Which Ì© price 4 Ì© 2 bedrm ($900)",
#  'Me too! Have lovely night xxx',
#  'Prepare pleasured :)',
#  'Hi.:)technical support.providing assistance us customer call email:)',
#  'if text way cup stop work. And BUS',
#  'Whens radio show?',
#  'Your unique user ID 1172. For removal send STOP 87239 customer services 08708034412',
#  "I'm sure still available though",
#  'watever reLation u built dis world thing remains atlast iz lonlines lotz n lot memories! feeling..',
#  'CHEERS LOU! YEAH WAS A GOODNITE SHAME U NEVA CAME! C YA GAILxx',
#  'Hi..i got money da:)',
#  'Hi, Mobile no.  &lt;#&gt;  added contact list www.fullonsms.com It great place send free sms people For visit fullonsms.com',
#  'Ok u tell wat time u coming later lor.',
#  "U repeat e instructions again. Wat's e road name ur house?",
#  'So many people seems special first sight, But remain special till last sight.. Maintain till life ends.. Sh!jas',
#  'Quite lor. But dun tell wait get complacent...',
#  'Sorry completely forgot * pop em round week still here?',
#  'U R THE MOST BEAUTIFUL GIRL IVE EVER SEEN. U R MY BABY COME AND C ME IN THE COMMON ROOM',
#  'O cant see join denis mina? Or denis want alone time',
#  'Sen told going join uncle finance cbe',
#  'Yup... Hey one day fri ask miwa jiayin take leave go karaoke ',
#  'Call me, senthil hsbc.',
#  'Especially since talk boston personal statement, lol! I woulda changed realized said nyc! It says boston now.',
#  'Indeed way either - !',
#  'Urgent -call 09066649731from Landline. Your complimentary 4* Ibiza Holiday å£10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150ppm 18+',
#  'Holy living christ taking long',
#  'ÌÏ thk wat eat tonight.',
#  "Thanx. Yup coming back sun. Finish dinner going back 2 hotel now. Time flies, we're tog 4 exactly mth today. Hope we'll haf many mths come...",
#  "We're opposite side dropped off",
#  "Yup. Izzit still raining heavily cos i'm e mrt can't c outside.",
#  'Send resume:-)',
#  'Gd luck 4 ur exams :-)',
#  "Or u ask next sat not. If make i'm ok lor.",
#  'Sorry uncle. I.ll keep touch',
#  'Saw Guys Dolls last night Patrick Swayze great',
#  'URGENT This 2nd attempt contact U. Your å£900 prize YESTERDAY still awaiting collection. To claim CALL NOW 09061702893',
#  'Santa calling! Would little ones like call Santa Xmas Eve? Call 09077818151 book time. Calls1.50ppm last 3mins 30s T&C www.santacalling.com',
#  'Just come home. I want u miserable',
#  'I dont know she.s getting messages',
#  "its cool tyler take we're gonna buy drop place later tonight. Our total order quarter, got enough?",
#  "The guy car shop flirting got phone number paperwork called texted me. I'm nervous course may address. Should call boss tell him, knowing may get fired?",
#  'Reverse cheating. That mathematics.',
#  'How plan manage that',
#  'Er, hello, things didn\x89Û÷t quite go plan \x89ÛÒ limping slowly home followed aa exhaust hanging off',
#  'Sorry delay. Yes masters',
#  'Call u finish come n pick u.',
#  'PRIVATE! Your 2004 Account Statement 078498****7 shows 786 unredeemed Bonus Points. To claim call 08719180219 Identifier Code: 45239 Expires 06.05.05',
#  "What's oga. Left phone home saw ur messages. Hope good. Have great weekend.",
#  "Don't worry though, I understand important I put place poorly thought punishment face worst thing ever happened me. Brb gonna go kill myself",
#  'Honey, pls find much sell Predicte Nigeria. And many times used. Its important reply monday',
#  "E admin building there? I might b slightly earlier... I'll call u i'm reaching...",
#  "fyi I'm usf now, swing room whenever",
#  'i call  &lt;#&gt;  min thats ok',
#  'Ummmmmaah Many many happy returns day dear sweet heart.. HAPPY BIRTHDAY dear',
#  'ÌÏ home work meh... ',
#  'Anything valuable 2 situations: First- Before getting it... Second- After loosing it...',
#  'Me too. Mark taking forever pick prescription pain coming back.',
#  "How's ur paper?",
#  'Got smaller capacity one? Quite ex...',
#  'Check Out Choose Your Babe Videos @ sms.shsex.netUN fgkslpoPW fgkslpo',
#  'Im good! I thinking you...',
#  'u r winner U ave specially selected 2 receive å£1000 cash 4* holiday (flights inc) speak live operator 2 claim 0871277810710p/min (18 )',
#  ':-) :-)',
#  'Not thought bout it... || Drink tap & spile seven. || Is pub gas st broad st canal. || Ok?',
#  'I going sleep. I tired travel.',
#  'Haha, I thinkin',
#  "Yup giving problems mayb i'll jus leave it...",
#  'Lol no. Just trying make day little interesting',
#  'How long get reply, defer admission til next semester',
#  'The word \\Checkmate\\" chess comes Persian phrase \\"Shah Maat\\" means; \\"the king dead..\\" Goodmorning.. Have good day..:)"',
#  'Po de :-):):-):-):-). No need job aha.',
#  'Rats. Hey u ever vote next themes?',
#  'New Mobiles 2004, MUST GO! Txt: NOKIA No: 89545 & collect today! From ONLY å£1. www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 TXTAUCTION.',
#  'I hope pee burns tonite.',
#  'OH RITE. WELL IM WITH MY BEST MATE PETE, WHO I WENT OUT WITH 4 A WEEK+ NOW WERE 2GEVA AGAIN. ITS BEEN LONGER THAN A WEEK.',
#  "Yay can't wait party together!",
#  '....photoshop makes computer shut down.',
#  'All boys made fun today. Ok problem. I sent one message fun',
#  "That's one issues california okay. No snow manageable",
#  'PRIVATE! Your 2003 Account Statement shows 800 un-redeemed S. I. M. points. Call 08715203652 Identifier Code: 42810 Expires 29/10/0',
#  'Hmmm.... Mayb try e shoppin area one, forgot e name hotel...',
#  'Awesome, gonna soon later tonight?',
#  'I need details online job.',
#  'YOU HAVE WON! As valued Vodafone customer computer picked YOU win å£150 prize. To collect easy. Just call 09061743386 ',
#  'Missing too.pray inshah allah',
#  'Pls help tell Ashley cant find number oh',
#  'I escape theatre now. . Going watch KAVALAN minutes',
#  'S.this increase chance winning.',
#  'either way works me. I  &lt;#&gt;  years old. Hope doesnt bother you.',
#  'Maybe find something else instead???',
#  'Gain rights wife.dont demand it.i trying husband too.Lets see',
#  'I liked new house',
#  "I'm fine. Hope also",
#  'Also north carolina texas atm, would go gre site pay test results sent.',
#  'Same u...',
#  'yes baby! I need stretch open pussy!',
#  'Thanks  ! Or bomb date phone wanted say! ',
#  'Ok...',
#  'Hey, guy I know breathing neck get bud, anyway able get half track usf tonight?',
#  '\\Response\\" one powerful weapon 2 occupy place others \'HEART\'... So',
#  'Nokia phone lovly..',
#  '**FREE MESSAGE**Thanks using Auction Subscription Service. 18 . 150p/MSGRCVD 2 Skip Auction txt OUT. 2 Unsubscribe txt STOP CustomerCare 08718726270',
#  'Bored housewives! Chat n date now! 0871750.77.11! BT-national rate 10p/min landlines!',
#  'Sorry da..today wont come play..i driving clas..',
#  "I'm really sorry I lit hair fire",
#  'Oh! Shit, I thought trip! Loooooool ... That makes SO much sense ... *grins* sofa reference ... The \\sleep couch\\" link sent ... Wasn\'t went trip ? Oh ... And babe go celebration rents?"',
#  'Okey dokey swashbuckling stuff oh.',
#  'Watching cartoon, listening music &amp; eve go temple &amp; church.. What u?',
#  '1. Tension face 2. Smiling face 3. Waste face 4. Innocent face 5.Terror face 6.Cruel face 7.Romantic face 8.Lovable face 9.decent face  &lt;#&gt; .joker face.',
#  "Dip's cell dead. So coming him. U better respond else shall come back.",
#  'Well. You know mean. Texting',
#  'Hi dis yijue would happy work wif Ì_ gek1510...',
#  'Lol! Oops sorry! Have fun. ',
#  'Wat happened cruise thing',
#  'I know dat feelin Pete! Wuld get em , nuther place nuther time mayb?',
#  'lyricalladie(21/F) inviting friend. Reply YES-910 NO-910. See her: www.SMS.ac/u/hmmross STOP? Send STOP FRND 62468',
#  "The world's happiest frnds never characters... Dey best understanding differences...",
#  'No 1 POLYPHONIC tone 4 ur mob every week! Just txt PT2 87575. 1st Tone FREE ! get txtin tell ur friends. 150p/tone. 16 reply HL 4info',
#  'Yeah open chat click friend lists. Then make list. Easy pie',
#  "alright tyler's got minor crisis home sooner thought asap",
#  'When/where I pick up',
#  'As usual u call ard 10 smth.',
#  "New Theory: Argument wins SITUATION, loses PERSON. So dont argue ur friends just.. . . . kick &amp; say, I'm always correct.!",
#  'For many things antibiotic used chest abdomen gynae infections even bone infections.',
#  "Poor girl can't go one day lmao",
#  'Or 6times',
#  'Todays Vodafone numbers ending 4882 selected receive å£350 award. If number matches call 09064019014 receive å£350 award.',
#  'You pls make note she.s exposed to. Also find school anyone else vomiting. Is dog cat house? Let know later.',
#  'Japanese Proverb: If one Can it, U Can it, If none Can it,U must Indian version: If one Can it, LET HIM DO it.. If none Can it,LEAVE it!! And finally Kerala version: If one it, Stop it.. If none it, Make strike ...',
#  'Sounds like could lot time spent chastity device boy ... *grins* ... Or take beatings like good dog. Going lounge nice long bath ?',
#  'Its worse if uses half way stops. Its better complete it.',
#  'Miserable. They tell u side effects birth control massive gut wrenching cramps first 2 months. I sleep last night.',
#  'Send new number',
#  'Convey regards him',
#  'Want latest Video handset? 750 anytime network mins? Half price line rental? Reply call 08000930705 delivery tomorrow',
#  '2 half years missed friendship:-)',
#  'I cant pick phone right now. Pls send message',
#  "Oh fuck's sake like tallahassee",
#  'Haha, first person I gonna ask',
#  'ou guaranteed latest Nokia Phone, 40GB iPod MP3 player å£500 prize! Txt word: COLLECT No: 83355! IBHltd LdnW15H 150p/Mtmsgrcvd18',
#  'Taka lor. Wat time u wan 2 come n look 4 us?',
#  '* FREE* POLYPHONIC RINGTONE Text SUPER 87131 get FREE POLY TONE week now! 16 SN PoBox202 NR31 7ZS subscription 450pw',
#  '\\I;m reaching another 2 stops.\\""',
#  "no, *didn't* mean post it. I wrote it, like many times i've ritten stuff you, let sit there. WAS feeling time. I angry. Before left, hit send, stop. It there. I checked phone got car. It there. You said sleep, bored. So THAT time clean, fold laundry, etc.? At least make bed?",
#  'Warner Village 83118 C Colin Farrell SWAT wkend @Warner Village & get 1 free med. Popcorn!Just show msg+ticket@kiosk.Valid 4-7/12. C t&c @kiosk. Reply SONY 4 mre film offers',
#  'Will come online today night',
#  'Then anything special?',
#  "I'm solihull, | want anything?",
#  'Will do. Have good day',
#  'WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL HOSPITAL 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE',
#  'Love holiday Monday feeling even I go dentists hour',
#  'I way tirupur.',
#  'Goal! Arsenal 4 (Henry, 7 v Liverpool 2 Henry scores simple shot 6 yards pass Bergkamp give Arsenal 2 goal margin 78 mins.',
#  "You've already got flaky parent. It'snot supposed child's job support parent...not they're The Ride age anyway. I'm supposed support you. And i've hurt you. unintentional. But hurt nonetheless.",
#  'We took hooch walk toaday fell over! Splat! Grazed knees everything! Should stayed home! See tomorrow! ',
#  'Just dropped em off, omw back now',
#  'This 2nd time tried 2 contact u. U 750 Pound prize. 2 claim easy, call 08712101358 NOW! Only 10p per min. BT-national-rate',
#  'Sitting mu waiting everyone get suite I take shower',
#  'Re call; You see facebook huh?',
#  'G says never answer texts, confirm/deny',
#  'Its common hearin How r u? Wat r u doing? How ur day? So let ask u something different. Did u smile today? If not, now.... Gud evng.',
#  'Hi Dear Call urgnt. I know whats problem. You want work problem least tell me. Wating reply.',
#  'Oh yah... We never cancel leh... Haha ',
#  'We go 4 e normal pilates intro...  ',
#  'Ok... Let u noe leave house.',
#  'Oh yes, like torture watching england?',
#  'Wanna art?! :D',
#  'Just hopeing wasn\x89Û÷t pissed remember gone sisters something!',
#  'Got takes 2 take part WRC Rally Oz? U Lucozade Energy! Text RALLY LE 61200 (25p), see packs lucozade.co.uk/wrc & itcould u!',
#  'Hi, SEXYCHAT girls waiting text them. Text great night chatting. send STOP stop service',
#  "Good morning, boytoy! How's yummy lips ? Where's sexy buns ? What do ? Do think ? Do crave ? Do need ?",
#  'Match started.india  &lt;#&gt;  2',
#  'Once free call sir.',
#  'Hey want anything buy:)',
#  "Hey babe, how's going ? Did ever figure going New Years ?",
#  'K..k.:)congratulation ..',
#  'G wants know fuck are',
#  'No cancelled yeah baby! Well sounds important understand darlin give ring later fone love Kate x',
#  'Tomarrow want got court. At  &lt;DECIMAL&gt; . So come bus stand 9.',
#  'ÌÏ go home liao? Ask dad pick 6...',
#  'Omg make wedding chapel frontierville? Why get good stuff?',
#  "I'm eatin lor, goin back work soon... E mountain deer show huh... I watch b4 liao, nice...",
#  'Check mail.i mailed varma kept copy regarding membership.take care.insha allah.',
#  'Wrong phone! This phone! I answer one assume people well',
#  'Anyway I think I secure anything here, lemme know want drive south chill',
#  "I'm already back home probably not",
#  'Great News! Call FREEFONE 08006344447 claim guaranteed å£1000 CASH å£2000 gift. Speak live operator NOW!',
#  'Hi Amy, sending free phone number couple days, give access adult parties...',
#  'I bus way calicut',
#  'Hi probably much fun get message thought id txt u cos im bored! james farting night',
#  'hi baby im sat bloody bus mo wont home 7:30 wanna somethin later? call later ortxt back jess xx',
#  'Welcome Select, O2 service added benefits. You call specially trained advisors FREE mobile dialling 402.',
#  "I lost 4 pounds since doc visit last week woot woot! Now I'm gonna celebrate stuffing face!",
#  'U coming back 4 dinner rite? Dad ask confirm wif u...',
#  "Doing masters. When buy bb cos sale how's bf",
#  'Ahhhh...just woken up!had bad dream u tho,so dont like u right :) didnt know anything comedy night guess im it.',
#  "I'm vivek:)i got call number.",
#  'Why u call lunch?',
#  "What mean left early check, cos i'm working 9-6.",
#  'I want  &lt;#&gt;  rs da:)do it?',
#  'A bit Ur smile hppnss, drop Ur tear sorrow, part Ur heart life, heart like mine wil care U, forevr GOODFRIEND',
#  'Yup ok...',
#  'I want see pretty pussy...',
#  'Dear Voucher holder Have next meal us. Use following link pc 2 enjoy 2 4 1 dining experiencehttp://www.vouch4me.com/etlp/dining.asp',
#  "A people game, I'm mall iouri kaila",
#  'URGENT! We trying contact U. Todays draw shows å£2000 prize GUARANTEED. Call 09058094507 land line. Claim 3030. Valid 12hrs only',
#  "You donate å£2.50 UNICEF's Asian Tsunami disaster support fund texting DONATE 864233. å£2.50 added next bill",
#  'Future planned tomorrow.....! result today...! Do best present... enjoy future.',
#  'I cme want go hos 2morow. After wil cme. This got dear do. She didnt say time',
#  'We supposed meet discuss abt trip... Thought xuhui told you? In afternoon. Thought go lesson that',
#  'Hey come online! Use msn... We there',
#  "I'm fine. Hope good. Do take care.",
#  "Oops I shower u called. Hey parking garage collapsed university hospital. See I'm crazy. Stuff like DOES happen.",
#  'Aiyo u poor thing... Then u dun wan 2 eat? U bathe already?',
#  'Yar... I tot u knew dis would happen long ago already.',
#  'You gorgeous! keep pix cumming :) thank you!',
#  'A boy late 2 home. His father: \\POWER OF FRNDSHIP\\""',
#  'JADE ITS PAUL. Y DIDNåÕT U TXT ME? DO U REMEMBER ME FROM BARMED? I WANT 2 TALK 2 U! TXT ME',
#  'Spending new years brother family. Lets plan meet next week. Are ready spoiled? :)',
#  'So u today?',
#  'I said okay. Sorry',
#  'Slept? I thinkThis time ( &lt;#&gt;  pm) dangerous',
#  'Networking job there.',
#  'goldviking (29/M) inviting friend. Reply YES-762 NO-762 See him: www.SMS.ac/u/goldviking STOP? Send STOP FRND 62468',
#  'Dont let studying stress out. L8r.',
#  "That's u haf 2 keep busy...",
#  "No rushing. I'm working. I'm school rush go hungry.",
#  'Which channel:-):-):):-).',
#  "So telling I coulda real Valentine I wasn't? U never pick NOTHING!!",
#  'Phony å£350 award - Todays Voda numbers ending XXXX selected receive å£350 award. If match please call 08712300220 quoting claim code 3100 standard rates app',
#  'We made it! Eta taunton 12:30 planned, hope that\x89Û÷s still okday?! Good see you! :-xx',
#  "I'm hungry buy smth home...",
#  '\\HEY KATE',
#  'My drive read. I need write',
#  'Just looked addie goes back Monday, sucks her',
#  'Happy new year. Hope good semester',
#  'Esplanade lor. Where else...',
#  'Can talk me..',
#  'Hmph. Go head, big baller.',
#  'Well like actually called someone punto. That woulda worse.',
#  'Nope. Since ayo travelled, forgotten guy',
#  'You still around? Looking pick later',
#  'CDs 4u: Congratulations ur awarded å£500 CD gift vouchers å£125 gift guaranteed & Freeentry 2 å£100 wkly draw xt MUSIC 87066 TnCs www.ldew.com1win150ppmx3age16 ',
#  "There's someone year  &lt;#&gt;  toyota camry like mr olayiwola's own. Mileage  &lt;#&gt; k.its clean need know much sell for. If raise dough soon landing sell. Holla back.",
#  'Guess pub im in? Im happy pig clover whatever saying is! ',
#  'ILL B DOWN SOON',
#  'Oh k. . I come tomorrow',
#  'Go fool dont cheat others ok',
#  'My mobile number.pls sms ur mail id.convey regards achan,amma.Rakhesh.Qatar',
#  "By way, 'rencontre' meet again. Mountains dont....",
#  'You WON guaranteed å£1000 cash å£2000 prize. To claim yr prize call customer service representative 08714712412 10am-7pm Cost 10p',
#  'U attend ur driving lesson many times wk n day?',
#  'Uncle G, checking you. Do rewarding month',
#  "Hello boytoy ! Geeee ... I'm missing today. I like send tm remind I'm thinking ... And loved ... *loving kiss*",
#  'I think two still need get cash def ready 9',
#  'Hey gals...U wanna meet 4 dinner nÌÂte? ',
#  "Dear 0776xxxxxxx U've invited XCHAT. This final attempt contact u! Txt CHAT 86688 150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL LDN 18yrs",
#  'Babe ! What ? Where ? Who talking ? Do think ? Are good boy? Are missing me? Do love ?',
#  'Great! How office today?',
#  "It's cool, last little while. Getting time soon?",
#  ':-( sad puppy noise',
#  'Yes possible dint try. Pls dont tell one k',
#  'Anyway holla whenever around I need excuse go creep people sarasota',
#  'Where you. What happen',
#  'I gonna ask lol think 7',
#  'Ur cash-balance currently 500 pounds - maximize ur cash-in send GO 86688 150p/meg. CC: 08718720201 HG/Suite342/2lands Row/W1j6HL',
#  'PRIVATE! Your 2003 Account Statement shows 800 un-redeemed S.I.M. points. Call 08715203685 Identifier Code:4xx26 Expires 13/10/04',
#  'Go chase run crossing street',
#  "I'd like tell deepest darkest fantasies. Call 09094646631 60p/min. To stop texts call 08712460324 (nat rate)",
#  'Is coming friday leave pongal?do get news work place.',
#  'Hey... Very inconvenient sis huh?',
#  'Ok vl..do u know got adsense approved..',
#  '* Was really good see day dudette, missing you!',
#  'I want go perumbavoor',
#  'How many times told stage use laugh. You listen aha.',
#  "You believe true. It's Incredible Txts! Reply G learn truly amazing things blow mind. From O2FWD 18p/txt",
#  '(You hear me)',
#  'Thanks talk saturday. You dear me. I cherish brother role model.',
#  'Pls clarify back open return ticket preponed go back kerala.',
#  'Natalie (20/F) inviting friend. Reply YES-165 NO-165 See her: www.SMS.ac/u/natalie2k9 STOP? Send STOP FRND 62468',
#  'She ran younger man. make pretty babies together :)',
#  'Jamster! To get free wallpaper text HEART 88888 now! T&C apply. 16 only. Need Help? Call 08701213186.',
#  'O ic lol. Should play 9 doors sometime yo',
#  'Dunno, dad said coming home 2 bring us 4 lunch. Yup go w u lor. I call u reach school lor...',
#  'We sent JD Customer Service cum Accounts Executive ur mail id, For details contact us',
#  'Desires- u going doctor 4 liver. And get bit stylish. Get ur hair managed. Thats it.',
#  'Hmmm.still dont opener?',
#  'Yeah basically time next week get away mom &amp; get 3',
#  'Edison rightly said, \\A fool ask questions wise man answer\\" Now know us speechless ViVa.. GM',
#  'I vote wherever heart guides me',
#  'With sis lor... We juz watched italian job.',
#  'Tick, tick, tick .... Where ? I could die loneliness know ! *pouts* *stomps feet* I need ...',
#  'Lmao know well...',
#  'Double Mins & Double Txt & 1/2 price Linerental Latest Orange Bluetooth mobiles. Call MobileUpd8 latest offers. 08000839402 call2optout/LF56',
#  "Am train back northampton i'm afraid not! I'm staying skyving today ho ho! Will around wednesday though. Do fancy comedy club week way?",
#  'Goodnight da thangam I really miss u dear.',
#  "Hey next sun 1030 there's basic yoga course... bugis... We go that... Pilates intro next sat.... Tell time r free",
#  'Geeeee ... Your internet really bad today, eh ?',
#  'Free video camera phones Half Price line rental 12 mths 500 cross ntwk mins 100 txts. Call MobileUpd8 08001950382 Call2OptOut/674',
#  'I think disturbing da',
#  "Sorry, I'll call  later. I meeting sir.",
#  "Havent stuck orchard dad's car. Going 4 dinner now. U leh? So r free tonight?",
#  'Ok also wan 2 watch e 9 pm show...',
#  'I dunno lei... Like dun haf...',
#  'But brother transfered  &lt;#&gt;  +  &lt;#&gt; . Pa.',
#  "I calls later. Afternoon onwords mtnl service get problem south mumbai. I hear cann't listen me.",
#  '83039 62735=å£450 UK Break AccommodationVouchers terms & conditions apply. 2 claim mustprovide claim number 15541 ',
#  'Talk g x that',
#  'Hai dear friends... This new &amp; present number..:) By Rajitha Raj (Ranju)',
#  "5p 4 alfie Moon's Children need song ur mob. Tell ur m8s. Txt Tone charity 8007 Nokias Poly charity polys: zed 08701417012 profit 2 charity.",
#  'As different styles?',
#  'WIN å£200 Shopping spree every WEEK Starting NOW. 2 play text STORE 88039. SkilGme. TsCs08714740323 1Winawk! age16 å£1.50perweeksub.',
#  'Gud ni8 dear..slp well..take care..swt dreams..Muah..',
#  'I want sent  &lt;#&gt; mesages today. Thats y. Sorry hurts',
#  'This 2nd attempt contract U, weeks top prize either å£1000 cash å£200 prize. Just call 09066361921',
#  "Well, i'm glad find totally disagreeable ... Lol",
#  'Guy, flash now. If go call me, call me. How madam. Take care oh.',
#  'Do want New Nokia 3510i colour phone DeliveredTomorrow? With 300 free minutes mobile + 100 free texts + Free Camcorder reply call 08000930705.',
#  'Mark works tomorrow. He gets 5. His work house meet u afterwards.',
#  '\\Keep ur problems ur heart',
#  'Yeah, give call got minute',
#  '\\HI BABE UAWAKE?FEELLIKW SHIT.JUSTFOUND OUT VIA ALETTER THATMUM GOTMARRIED 4thNOV.BEHIND OURBACKS åÐ FUCKINNICE!SELFISH',
#  'Amazing : If rearrange letters gives meaning... Dormitory = Dirty room Astronomer = Moon starer The eyes = They see Election results = Lies lets recount Mother-in-law = Woman Hitler Eleven plus two =Twelve plus one Its Amazing... !:-)',
#  'Aiya discuss later lar... Pick Ì_ 4 it?',
#  'Hey happy birthday...',
#  'Sorry missed call. Can please call back.',
#  'Omg one thing another. My cat worms :/ bad day end?',
#  'Good morning, im suffering fever dysentry ..will able come office today.',
#  'I wont anything de.',
#  'What type stuff sing?',
#  "St andre, virgil's cream",
#  'No no. I check rooms befor activities',
#  'My fri ah... Okie lor,goin 4 drivin den go shoppin tt...',
#  'Gokila talking aha:)',
#  'Hi Shanil,Rakhesh here.thanks,i exchanged uncut diamond stuff.leaving back. Excellent service Dino Prem.',
#  'K.k.this month kotees birthday know?',
#  "But i'm really really broke oh. No amount small even  &lt;#&gt; ",
#  'Sorry mates phone didnt write love Kate',
#  'TheMob>Hit link get premium Pink Panther game, new no. 1 Sugababes, crazy Zebra animation badass Hoody wallpaper-all 4 FREE!',
#  'Ah, well confuses things, doesnt it? I thought friends now. Maybe wrong thing already sort invited -tho may come cos money.',
#  'Aight, call close',
#  'Nope thats fine. I might nap tho! ',
#  'This msg mobile content order It resent previous attempt failed due network error Queries customersqueries@netvision.uk.com',
#  'In news hassling get weed week andres money. HAUGHAIGHGTUJHYGUJ',
#  'A Boy loved gal. He propsd bt didnt mind. He gv lv lttrs, Bt frnds threw thm. Again boy decided 2 aproach gal , dt time truck speeding towards gal. Wn 2 hit girl,d boy ran like hell n saved her. She asked \'hw cn u run fast?\' D boy replied \\Boost secret energy\\" n instantly girl shouted \\"our energy\\" n Thy lived happily 2gthr drinking boost evrydy Moral story:- I hv free msgs:D;): gud ni8"',
#  'I wnt buy BMW car urgently..its vry urgent.but hv shortage  &lt;#&gt; Lacs.there source arng dis amt. &lt;#&gt; lacs..thats prob',
#  'Ding ya break fassyole! Blacko londn',
#  'I REALLY NEED 2 KISS U I MISS U MY BABY FROM UR BABY 4EVA',
#  'The sign maturity start saying big things.. But actually is, start understanding small things... *HAVE A NICE EVENING* BSLVYL',
#  'Oh got many responsibilities.',
#  'You 1 new message. Please call 08715205273',
#  "I've reached sch already...",
#  'December only! Had mobile 11mths+? You entitled update latest colour camera mobile Free! Call The Mobile Update VCo FREE 08002986906 ',
#  'U definitely need module e humanities dis sem izzit? U wan 2 take modules 1st?',
#  'Argh fuck nobody town ;_;',
#  'Get 3 Lions England tone, reply lionm 4 mono lionp 4 poly. 4 go 2 www.ringtones.co.uk, original n best. Tones 3GBP network operator rates apply.',
#  'Thanks. Fills complete calm reassurance! ',
#  'Aslamalaikkum....insha allah tohar beeen muht albi mufti mahfuuz...meaning here....',
#  'Are driving training?',
#  'Lol real. She told dad I cancer',
#  'PRIVATE! Your 2003 Account Statement 078',
#  'Oops I it,  &lt;#&gt; ?',
#  '\\NOT ENUFCREDEIT TOCALL.SHALL ILEAVE UNI AT 6 +GET A BUS TO YOR HOUSE?\\""',
#  'Hi Chikku, send nice msgs',
#  'He impossible argue always treats like sub, like never released ... Which I remind necessary',
#  'After work ah... Den 6 plus lor... U workin oso rite... Den go orchard lor, place go liao...',
#  'To wonderful Okors, great month. We cherish guys wish well day. MojiBiola',
#  'Cuz ibored. And wanna study',
#  'Wot wed nite I 3 til 9!',
#  'Rose red,red blood,blood heart,heart u. But u me.... Send tis ur friends.. Including me.. If u like me.. If u get back, 1-u r poor relation! 2-u need 1 support 3-u r frnd 2 many 4-some1 luvs u 5+- some1 praying god marry u.:-) try it....',
#  'Any way doing.',
#  "That sucks. I'll go u hair. You'll free right?",
#  "it's still working. And time also tried adding zeros. That savings. The checking  &lt;#&gt; ",
#  'Hmm... Dunno leh, mayb bag 4 goigng dat small. Or jus anything except perfume, smth dat keep.',
#  'Sday joined.so training started today:)',
#  'Sorry * grocers.',
#  'There nice pubs near Frankie n Bennys near warner cinema?',
#  'YOU VE WON! Your 4* Costa Del Sol Holiday å£5000 await collection. Call 09050090044 Now toClaim. SAE, TC s, POBox334, Stockport, SK38xh, Costå£1.50/pm, Max10mins',
#  'Yup... I havent before... You want go yoga? I call book ',
#  "Oh shut it. Omg yesterday I dream I 2 kids boys. I pissed. Not kids boys. I even told mark dream changing diapers cause I'm getting owed face.",
#  'Yeah I imagine would really gentle. Unlike docs treat patients like turkeys.',
#  'FREE 1st week! No1 Nokia tone 4 ur mobile every week txt NOKIA 8077 Get txting tell ur mates. www.getzed.co.uk POBox 36504 W45WQ 16+ norm150p/tone',
#  'Now started dont stop. Just pray good ideas anything see help guys i.ll forward link.',
#  'Hi darlin im helens fone im gonna b princes 2 nite please come tb love Kate',
#  "I'm office da:)where you?",
#  "Aiyar u poor thing... I give u support k... Jia you! I'll think u...",
#  'Oh unintentionally bad timing. Great. Fingers  trains play along! Will give fifteen min warning.',
#  'Get garden ready summer FREE selection summer bulbs seeds worth å£33:50 The Scotsman Saturday. To stop go2 notxt.co.uk',
#  'K..then come wenever u lik come also tel vikky come getting free time..:-)',
#  'Pls call da. What happen.',
# ...
#  'I reach ur home  &lt;#&gt;  minutes',
#  "Babe, I'm answering you, can't see ? Maybe better reboot YM ... I got photo ... It's great !",
#  'Hi.what think match?',
#  'I know thinkin malaria. But relax, children cant handle malaria. She would worse gastroenteritis. If takes enough replace loss temp reduce. And give malaria meds vomit. Its self limiting illness means days completely stop',
#  'Dai downloaded exe file run exe installing.',
#  'It yesterday true true.',
#  'K.k.how business now?',
#  '3 pa selected.',
#  'Natalja (25/F) inviting friend. Reply YES-440 NO-440 See her: www.SMS.ac/u/nat27081980 STOP? Send STOP FRND 62468',
#  'I keep ten rs shelf:) buy two egg.',
#  'I late. I at',
#  'Well thats nice. Too bad cant eat it',
#  'I accidentally brought em home box',
#  'Pls needs dat slowly vomit more.',
#  'I take exam march 3',
#  'Jane babes goin 2 wrk, feel ill lst nite. Foned already cover 4 chuck.:-)',
#  '5 nights...We nt staying port step liao...Too ex',
#  'If I die I want u stuffs.',
#  '\\OH FUCK. JUSWOKE UP IN A BED ON A BOATIN THE DOCKS. SLEPT WID 25 YEAR OLD. SPINOUT! GIV U DA GOSSIP L8R. XXX\\""',
#  'Smile Pleasure Smile Pain Smile trouble pours like Rain Smile sum1 Hurts U Smile becoz SOMEONE still Loves see u Smiling!!',
#  "Prabha..i'm soryda..realy..frm heart i'm sory",
#  "I re-met alex nichols middle school turns he's dealing!",
#  'PRIVATE! Your 2003 Account Statement <fone no> shows 800 un-redeemed S. I. M. points. Call 08715203656 Identifier Code: 42049 Expires 26/10/04',
#  'It means u could keep ur words.',
#  "Nope, I'm still market",
#  "I realise busy guy i'm trying bother. I get exams outta way try cars. Do gr8 day",
#  'YOU ARE CHOSEN TO RECEIVE A å£350 AWARD! Pls call claim number 09066364311 collect award selected receive valued mobile customer.',
#  'Hey project. Started aha da.',
#  'Ok cool. See ya then.',
#  'Am uworld site. Am buying qbank buying self assessment also?',
#  'Your opinion me? 1. Over 2. Jada 3. Kusruthi 4. Lovable 5. Silent 6. Spl character 7. Not matured 8. Stylish 9. Simple Pls reply..',
#  'Someonone know trying contact via dating service! To find could call mobile landline 09064015307 BOX334SK38ch ',
#  'Yeah I still give ride',
#  "Jay wants work first, how's 4 sound?",
#  'Gud gud..k, chikku tke care.. sleep well gud nyt',
#  'Its part checking IQ',
#  'Hmm thinking lor...',
#  "Of course ! Don't tease ... You know I simply must see ! *grins* ... Do keep posted prey ... *loving smile* *devouring kiss*",
#  'thanks temales wonderful. Thank. Have great week.',
#  'Thank princess! I want see nice juicy booty...',
#  "Haven't eaten day. I'm sitting staring juicy pizza I can't eat it. These meds ruining life.",
#  'Gud ni8 dear..slp well..take care..swt dreams..Muah..',
#  'U come n search tat vid..not finishd..',
#  "K I'm leaving soon, little 9",
#  'Urgent! Please call 09061213237 landline. å£5000 cash 4* holiday await collection. T &Cs SAE PO Box 177 M227XY. 16+',
#  'Yeah work fine, started last week, stuff before, dull easy guys fun!',
#  'You studies alone without anyones help. If cant need study.',
#  'Please tell car keys purse',
#  'I didnt get anything da',
#  'Ok... Sweet dreams...',
#  'Well big surprise!',
#  'As usual..iam fine, happy &amp; well..:)',
#  '1 cbe. 2 chennai.',
#  'Can help u swoop picking u wherever ur birds r meeting u want.',
#  'If anyone calls treadmill say buy it. Make sure working. I found ad Craigslist selling $ &lt;#&gt; .',
#  'I absolutely LOVE South Park! I recently started watching office.',
#  'Did see film:)',
#  'Pls speak me. I wont ask anything friendship.',
#  'Storming msg: Wen u lift phne, u say \\HELLO\\" Do u knw wt real meaning HELLO?? . . . It\'s name girl..! . . . Yes.. And u knw dat girl?? \\"Margaret Hello\\" She girlfrnd f Grahmbell invnted telphone... . . . . Moral:One 4get name person',
#  'Gud ni8.swt drms.take care',
#  'HI DARLIN ITS KATE ARE U UP FOR DOIN SOMETHIN TONIGHT? IM GOING TO A PUB CALLED THE SWAN OR SOMETHING WITH MY PARENTS FOR ONE DRINK SO PHONE ME IF U CAN',
#  'Anything lar Ì_ going home 4 dinner?',
#  '\\ER',
#  "If don't, prize go another customer. T&C www.t-c.biz 18+ 150p/min Polo Ltd Suite 373 London W1J 6HL Please call back busy ",
#  'Did u fix teeth?if asap.ok take care.',
#  'So u wan 2 come dinner tonight not?',
#  'Hello.How u doing?What u 2?When u b moving flat, cos I need arrange pick lamp, etc. Take care. Hello caroline!',
#  'Its late:)but k.wish same.',
#  'Hi. Hope ur day * good! Back walk, table booked half eight. Let know ur coming over.',
#  'Oh yeah clearly fault',
#  'Dunno leh cant remember mayb lor. So wat time r meeting tmr?',
#  "Best msg: It's hard person, u know one step foward make u fall love.. &amp; One step back ruin ur friendship.. good night:-) ...",
#  'URGENT! Your Mobile number awarded å£2000 prize GUARANTEED. Call 09061790126 land line. Claim 3030. Valid 12hrs 150ppm',
#  'Helloooo... Wake up..! \\Sweet\\" \\"morning\\" \\"welcomes\\" \\"You\\" \\"Enjoy\\" \\"This Day\\" \\"with full joy\\".. \\"GUD MRNG\\"."',
#  'Vikky, come around  &lt;TIME&gt; ..',
#  'And that, princess? :)',
#  'I gone get info bt dont know do',
#  'Yeah, probably while',
#  'Sent ur email id soon',
#  'URGENT! You 1 week FREE membership å£100,000 Prize Jackpot! Txt word: CLAIM No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18',
#  "I'm still pretty weak today .. Bad day ?",
#  "Hey ! Don't forget ... You MINE ... For ME ... My possession ... MY property ... MMM ... *childish smile* ...",
#  "An excellent thought misundrstud frnd: I knw u hate bt day wen u'll knw truth u'll hate urself:-( Gn:-)",
#  'Hey! Congrats 2u2. id luv 2 ive 2 go home!',
#  'Dear you. Call me',
#  'Xy trying smth now. U eat already? We havent...',
#  'Urgent! Please call 09061213237 landline. å£5000 cash luxury 4* Canary Islands Holiday await collection. T&Cs SAE PO Box 177. M227XY. 150ppm. 16+',
#  'I donno genes something',
#  'XMAS iscoming & ur awarded either å£500 CD gift vouchers & free entry 2 r å£100 weekly draw txt MUSIC 87066 TnC www.Ldew.com1win150ppmx3age16subscription ',
#  "Alex says he's ok ok it",
#  'Are u coming funeral home',
#  "My darling sister. How doing. When's school resuming. Is minimum wait period reapply? Do take care",
#  'I.ll hand phone chat wit u',
#  "Well good morning mr . Hows london treatin' ya treacle?",
#  "I can't make tonight",
#  'At WHAT TIME come tomorrow',
#  'About  &lt;#&gt; bucks. The banks fees fixed. Better call bank find out.',
#  'I can. But tell quite long, cos finish film yet...',
#  'Pls ask macho much budget bb bold 2 cos saw new one  &lt;#&gt;  dollars.',
#  '\\Hi missed Call mumHas beendropping red wine theplace! adress?\\""',
#  'Ill 3 mins look me',
#  'What  leave.',
#  "I'm coming back Thursday. Yay. Is gonna ok get money. Cheers. Oh yeah you. Everything alright. Hows school. Or call work now",
#  'Jolly good! By way,  give u tickets sat eve 7.30. Speak x',
#  "yeah, that's I thinking",
#  "K.k:)i'm going tirunelvali week see uncle ..i already spend amount taking dress .so want money.i give feb 1",
#  'Here got ur favorite oyster... N got favorite sashimi... Ok lar dun say already... Wait ur stomach start rumbling...',
#  'My sister going earn da.',
#  'Get official ENGLAND poly ringtone colour flag yer mobile tonights game! Text TONE FLAG 84199. Optout txt ENG STOP Box39822 W111WX å£1.50',
#  'Hahaha..use brain dear',
#  'Jus finish watching tv... U?',
#  "K, fyi I'm back parents' place south tampa I might need deal somewhere else",
#  'Good morning, Love ... I go sleep wish great day full feeling better opportunity ... You last thought babe, I LOVE YOU *kiss*',
#  'Kothi print marandratha.',
#  'But havent got da topic yet rite?',
#  "Ok problem... Yup i'm going sch 4 rem correctly...",
#  "Thanks, I'll keep mind",
#  "Aah bless! How's arm?",
#  'Dear Sir,Salam Alaikkum.Pride Pleasure meeting today Tea Shop.We pleased send contact number Qatar.Rakhesh Indian.Pls save Number.Respectful Regards.',
#  'Gal n boy walking park. gal-can hold ur hand? boy-y? u think would run away? gal-no, jst wana c feels walking heaven prince..GN:-)',
#  'What makes happy?',
#  'Wishing wonderful week.',
#  'Sweet heart you?',
#  'Sir, waiting letter.',
#  'Dude im longer pisces. Im aquarius now.',
#  'X course 2yrs. Just messages messenger lik r sending me',
#  'I think steyn surely get one wicket:)',
#  "Neither [in sterm voice] - i'm studying. All fine me! Not sure  thing resolved, tho. Anyway. Have fab hols",
#  'Garbage bags, eggs, jam, bread, hannaford wheat chex',
#  "No. It's pride. I'm almost  &lt;#&gt;  years old takin money kid. You're supposed deal stuff. This grownup stuff--why tell you.",
#  'Sounds better evening im costume. Im sure time finish tomorrow txt end.',
#  'My birthday feb  &lt;#&gt;  da. .',
#  'So wanna gym?',
#  "You'd like you? Jerk!",
#  'Are u awake? Is snow there?',
#  'And course make stink!',
#  'u r subscribed 2 TEXTCOMP 250 wkly comp. 1st wk?s free question follows, subsequent wks charged@150p/msg.2 unsubscribe txt STOP 2 84128,custcare 08712405020',
#  "No go. No openings room 'til thanksgiving without upcharge.",
#  'When guys planning coming over?',
#  'Wat Ì_ now?',
#  "My Parents, My Kidz, My Friends n My Colleagues. All screaming.. SURPRISE !! I waiting sofa.. ... ..... ' NAKED...!",
#  "No sir. That's 8-hr trip bus last week. Have another audition next wednesday think might drive time.",
#  'Do I? I thought I put back box',
#  "I'm home...",
#  'No one interested. May business plan.',
#  'Yup paragon... I havent decided whether 2 cut yet... Hee...',
#  'Good morning princess! Have great day!',
#  "Guai... ÌÏ shd haf seen he's naughty... ÌÏ free today? Can go jogging...",
#  'Aiyo cos sms Ì_ Ì_ neva reply wait 4 Ì_ reply lar. I tot Ì_ havent finish ur lab wat.',
#  "Living simple.. Loving also simple.. Laughing simple.. Winning tooo simple.. But, Being 'SIMPLE' difficult...;-) :-)",
#  'Tell something. Thats okay.',
#  'Ok',
#  "Hmm. Shall bring bottle wine keep us amused? Just joking! I'll still bring bottle. Red white? See tomorrow",
#  'This ur face test ( 1 2 3 4 5 6 7 8 9  &lt;#&gt;  ) select number tell ur face astrology.... waiting. quick reply...',
#  "Hey, iouri gave number, I'm wylie, ryan's friend",
#  "Yep get program. You're slacking.",
#  "I'm inside office..still filling forms.don know leave me.",
#  'I think mentor , 100 percent sure.',
#  'Call 09095350301 send girls erotic ecstacy. Just 60p/min. To stop texts call 08712460324 (nat rate)',
#  'Camera - You awarded SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.',
#  'A å£400 XMAS REWARD IS WAITING FOR YOU! Our computer randomly picked loyal mobile customers receive å£400 reward. Just call 09066380611',
#  "Just trying figure I'm suppose see couple different people week. We said we'd get together I set dates",
#  'IMPORTANT MESSAGE. This final contact attempt. You important messages waiting customer claims dept. Expires 13/4/04. Call 08717507382 NOW!',
#  'Hi mom might back later  &lt;#&gt; ',
#  'dating:i two these. Only started sent text talk sport radio last week. Any connection think coincidence?',
#  'Lol, oh got friend dog ?',
#  'Ok., problem u frm him? Wats matter?',
#  "K I'll head mins, see there",
#  'Do u konw waht rael FRIENDSHIP Im gving yuo exmpel: Jsut ese tihs msg.. Evrey splleing tihs msg wrnog.. Bt sitll yuo raed wihtuot ayn mitsake.. GOODNIGHT &amp; HAVE A NICE SLEEP..SWEET DREAMS..',
#  'I cant pick phone right now. Pls send message',
#  "I want leave. But i'm barely stay sane. fighting constantly helping.",
#  'The current leading bid 151. To pause auction send OUT. Customer Care: 08718726270',
#  'Free entry gr8prizes wkly comp 4 chance win latest Nokia 8800, PSP å£250 cash every wk.TXT GREAT 80878 http//www.gr8prizes.com 08715705022',
#  'Somebody set website play hold em using eve online spacebucks',
#  "Its sunny california. The weather's cool",
#  'You 1 new message. Call 0207-083-6089',
#  'I make there, squeezed  &lt;#&gt;  bucks dad',
#  'Good day You too.Pray me.Remove teeth painful maintaining stuff.',
#  'How babes. Hope ok. I shit nights sleep. I fell asleep 5.IåÕm knackered iåÕm dreading work tonight. What thou upto tonight. X',
#  'How friends help us problems? They give stupid suggestion Lands us another problem helps us forgt previous problem',
#  "I'm work. Please call",
#  'I gentle baby! Soon taking  &lt;#&gt;  inches deep inside tight pussy...',
#  'NOT MUCH NO FIGHTS. IT WAS A GOOD NITE!!',
#  'Ok.ok ok..then..whats ur todays plan',
#  'Nt joking seriously told',
#  'Watching ajith film ah?',
#  'Ooooooh I forgot tell u I get yoville phone',
#  "All done, handed in. Don't know mega shop asda counts celebration thats i'm doing!",
#  'I dont know exactly could ask chechi.',
#  'Dunno lei shd b driving lor cos go sch 1 hr oni.',
#  'As want custom officer discount oh.',
#  "That's necessarily respectful",
#  'Hi. Hope good day. Have better night.',
#  "And he's apparently bffs carly quick now",
#  'HARD BUT TRUE: How much show &amp;  express love someone....that much hurt leave get seperated...!\x8eö´\x89Ó_??\x8bÛ¬ud evening...',
#  'Babes I think I got ur brolly I left English wil bring 2mrw 4 u luv Franxx',
#  'Hi babe thanks coming even though didnt go well!i wanted bed! Hope see soon love kisses xxx',
#  'So gd got free ice cream... I oso wan...',
#  'Pls give prometazine syrup. 5mls  &lt;#&gt; mins later feed.',
#  'So many days since then?',
#  'Dear angry busy dear',
#  "Yup msg me: tat yijue? Then tot group mate cos meeting today mah... I'm askin Ì_ leaving earlier wat mah cos mayb Ì_ haf walk v far...",
#  '... Are pub?',
#  'There first time everything :)',
#  "Daddy, shu shu looking 4 u... U wan 2 tell u're singapore wat?",
#  'I ask u meeting da ge tmr nite...',
#  "Gr8. So handle victoria island traffic. Plus when's album due",
#  'Nite nite pocay wocay luv u n e thing 4eva I promise ring u 2morrowxxxx',
#  'East coast',
#  "You get chicken broth want ramen unless there's I know about",
#  'My slave! I want take 2 3 pictures today bright light cell phone! Bright light!',
#  'Nope. I forgot. Will show next week',
#  "So really. What to. How's masters. And on.",
#  "I'm bruce &amp; fowler I'm mom's car I can't park (long story)",
#  'I dont know oh. Hopefully month.',
#  "Hi elaine, today's meeting confirmed?",
#  'Ok k..sry knw 2 siva..tats askd..',
#  "Sorry, I'll call later",
#  'U horrible gal... U knew dat going wif yest n u still come n ask me...',
#  'Otherwise part time job na-tuition..',
#  'Oh yeah! And diet flew window',
#  'Santa Calling! Would little ones like call Santa Xmas eve? Call 09058094583 book time.',
#  'You didnt complete gist oh.',
#  'Er yeah, b 15:26, sorry! Just tell pub/cafe sit come wen u can',
#  'If make time tonight whenever cool, text whenever around',
#  'If I I paying attention',
#  'Thanx lot 4 ur help!',
#  "You're gonna way specific that",
#  'Jesus armand really trying tell everybody find',
#  "I'm wif buying tix lar...",
#  'Mode men left.',
#  "Am slow using biola's fne",
#  '\\What youdoing later? Sar xxx\\""',
#  "Hey i've booked 2 lessons sun liao...",
#  'Thank you. generally date brothas?',
#  'By way, make sure u get train worc foregate street shrub hill. Have fun night x',
#  "I thought i'd get watch, cos thats kind thing u get4an18th. And loves much!",
#  'You guaranteed 32000 award maybe even å£1000 cash claim ur award call free 0800 ..... (18+). Its legitimat efreefone number wat u think???',
#  "Good morning. At repair shop--the ONLY reason i'm hour.",
#  "And that's fine, I got enough bud last night least",
#  'I back. Good journey! Let know need receipts. Shall tell like pendent?',
#  'So takes away money worries',
#  'aight pick up, open tonight?',
#  'Latest News! Police station toilet stolen, cops nothing go on!',
#  'Sac needs carry on:)',
#  'Just sing HU. I think also important find someone female know place well preferably citizen also smart help navigate through. Even things like choosing phone plan require guidance. When doubt ask especially girls.',
#  'What???? Hello wats talks email address?',
#  'Except theres chick huge boobs.',
#  'Im wondering right now?',
#  'Wishing beautiful day. Each moment revealing even things keep smiling. Do enjoy it.',
#  '\\For sparkling shopping breaks 45 per person; call 0121 2025050 visit www.shortbreaks.org.uk\\""',
#  ...]

# %%
tokenizer = Tokenizer(num_words = 5572, oov_token='OOV')
tokenizer.fit_on_texts(train_articles)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'OOV': 1,
#  'i': 2,
#  'u': 3,
#  'call': 4,
#  'you': 5,
#  '2': 6,
#  'get': 7,
#  "i'm": 8,
#  'ur': 9,
#  'now': 10,
#  'gt': 11,
#  'lt': 12,
#  '4': 13,
#  'ok': 14,
#  'free': 15,
#  'go': 16,
#  'know': 17,
#  'me': 18,
#  'like': 19,
#  'good': 20,
#  'no': 21,
#  'it': 22,
#  'got': 23,
#  'come': 24,
#  'day': 25,
#  'love': 26,
#  'time': 27,
#  'send': 28,
#  'text': 29,
#  'want': 30,
#  'how': 31,
#  'going': 32,
#  "i'll": 33,
#  'txt': 34,
#  'do': 35,
#  'one': 36,
#  'home': 37,
#  'sorry': 38,
#  'need': 39,
#  'so': 40,
#  'r': 41,
#  'but': 42,
#  'still': 43,
#  'lor': 44,
#  'n': 45,
#  'today': 46,
#  'reply': 47,
#  'back': 48,
#  'dont': 49,
#  'if': 50,
#  'see': 51,
#  'stop': 52,
#  'k': 53,
#  'da': 54,
#  'please': 55,
#  'hi': 56,
#  'take': 57,
#  'tell': 58,
#  'new': 59,
#  'think': 60,
#  'what': 61,
#  'just': 62,
#  'mobile': 63,
#  'the': 64,
#  'we': 65,
#  'later': 66,
#  'my': 67,
#  'dear': 68,
#  'pls': 69,
#  'phone': 70,
#  '1': 71,
#  'ì': 72,
#  'your': 73,
#  'week': 74,
#  'msg': 75,
#  'well': 76,
#  'much': 77,
#  'and': 78,
#  'is': 79,
#  'night': 80,
#  'hope': 81,
#  'happy': 82,
#  'this': 83,
#  'claim': 84,
#  'then': 85,
#  'great': 86,
#  'to': 87,
#  'are': 88,
#  'can': 89,
#  'hey': 90,
#  'in': 91,
#  'message': 92,
#  'way': 93,
#  'yes': 94,
#  'that': 95,
#  'not': 96,
#  'c': 97,
#  'a': 98,
#  'say': 99,
#  'make': 100,
#  'wat': 101,
#  'e': 102,
#  'right': 103,
#  'oh': 104,
#  'work': 105,
#  'there': 106,
#  'prize': 107,
#  'www': 108,
#  'have': 109,
#  'tomorrow': 110,
#  'said': 111,
#  'already': 112,
#  'its': 113,
#  'only': 114,
#  'give': 115,
#  'amp': 116,
#  'number': 117,
#  'meet': 118,
#  'up': 119,
#  'really': 120,
#  'morning': 121,
#  'find': 122,
#  'miss': 123,
#  'yeah': 124,
#  'cash': 125,
#  'ask': 126,
#  'out': 127,
#  'would': 128,
#  '3': 129,
#  'life': 130,
#  'win': 131,
#  'every': 132,
#  'sure': 133,
#  'babe': 134,
#  'im': 135,
#  'let': 136,
#  'thanks': 137,
#  'cos': 138,
#  '150p': 139,
#  'lol': 140,
#  'also': 141,
#  'com': 142,
#  'he': 143,
#  'b': 144,
#  'last': 145,
#  'sent': 146,
#  't': 147,
#  'nokia': 148,
#  'urgent': 149,
#  'wait': 150,
#  'went': 151,
#  'feel': 152,
#  "i've": 153,
#  'did': 154,
#  'first': 155,
#  'pick': 156,
#  'someone': 157,
#  'buy': 158,
#  'all': 159,
#  'care': 160,
#  'around': 161,
#  'something': 162,
#  'min': 163,
#  'here': 164,
#  'anything': 165,
#  'uk': 166,
#  'could': 167,
#  'contact': 168,
#  '5': 169,
#  'even': 170,
#  'per': 171,
#  'late': 172,
#  'when': 173,
#  'cant': 174,
#  "can't": 175,
#  'keep': 176,
#  'v': 177,
#  'always': 178,
#  'us': 179,
#  'nice': 180,
#  'money': 181,
#  'service': 182,
#  'ya': 183,
#  'tone': 184,
#  'will': 185,
#  'place': 186,
#  'friends': 187,
#  'customer': 188,
#  'gonna': 189,
#  'on': 190,
#  'for': 191,
#  'where': 192,
#  'chat': 193,
#  'thing': 194,
#  '50': 195,
#  "that's": 196,
#  'special': 197,
#  'at': 198,
#  'sleep': 199,
#  'co': 200,
#  'soon': 201,
#  'waiting': 202,
#  'she': 203,
#  'getting': 204,
#  'done': 205,
#  'hello': 206,
#  'year': 207,
#  'many': 208,
#  'dun': 209,
#  'as': 210,
#  'help': 211,
#  'class': 212,
#  '18': 213,
#  'yet': 214,
#  'may': 215,
#  '16': 216,
#  'haha': 217,
#  'gud': 218,
#  'thk': 219,
#  'told': 220,
#  'wan': 221,
#  'tonight': 222,
#  'next': 223,
#  'x': 224,
#  'live': 225,
#  'things': 226,
#  'wish': 227,
#  'leave': 228,
#  'name': 229,
#  'man': 230,
#  'ìï': 231,
#  'use': 232,
#  'try': 233,
#  'sms': 234,
#  'best': 235,
#  'or': 236,
#  'people': 237,
#  'cs': 238,
#  's': 239,
#  'fine': 240,
#  '6': 241,
#  'guaranteed': 242,
#  'again': 243,
#  'job': 244,
#  'draw': 245,
#  "it's": 246,
#  'friend': 247,
#  'ill': 248,
#  'lunch': 249,
#  'am': 250,
#  'end': 251,
#  'too': 252,
#  'coming': 253,
#  'heart': 254,
#  'real': 255,
#  'yo': 256,
#  'wk': 257,
#  'holiday': 258,
#  'mind': 259,
#  'talk': 260,
#  'bit': 261,
#  'thought': 262,
#  'guess': 263,
#  'mins': 264,
#  'line': 265,
#  'lar': 266,
#  'word': 267,
#  'cost': 268,
#  'eat': 269,
#  'car': 270,
#  'check': 271,
#  'smile': 272,
#  'nothing': 273,
#  'better': 274,
#  'house': 275,
#  'chance': 276,
#  'days': 277,
#  '7': 278,
#  'god': 279,
#  'å£1': 280,
#  'they': 281,
#  'finish': 282,
#  'half': 283,
#  'long': 284,
#  'sir': 285,
#  'why': 286,
#  'luv': 287,
#  'ready': 288,
#  'start': 289,
#  'person': 290,
#  'enjoy': 291,
#  'world': 292,
#  'stuff': 293,
#  'trying': 294,
#  'lot': 295,
#  'offer': 296,
#  'early': 297,
#  'pay': 298,
#  'yup': 299,
#  'never': 300,
#  'meeting': 301,
#  'wanna': 302,
#  'thats': 303,
#  'aight': 304,
#  'account': 305,
#  'tv': 306,
#  'her': 307,
#  'ever': 308,
#  'receive': 309,
#  'speak': 310,
#  'room': 311,
#  'month': 312,
#  'sweet': 313,
#  'play': 314,
#  'awarded': 315,
#  'another': 316,
#  'girl': 317,
#  'dat': 318,
#  'big': 319,
#  'watch': 320,
#  'video': 321,
#  'shit': 322,
#  '1st': 323,
#  'xxx': 324,
#  'remember': 325,
#  'ringtone': 326,
#  'cool': 327,
#  'ah': 328,
#  'bed': 329,
#  '150ppm': 330,
#  'liao': 331,
#  'might': 332,
#  'box': 333,
#  'orange': 334,
#  'apply': 335,
#  'camera': 336,
#  'wont': 337,
#  'watching': 338,
#  'å£1000': 339,
#  'birthday': 340,
#  'jus': 341,
#  'reach': 342,
#  'two': 343,
#  'minutes': 344,
#  'quite': 345,
#  'sat': 346,
#  'actually': 347,
#  'rate': 348,
#  'latest': 349,
#  'look': 350,
#  'pa': 351,
#  'looking': 352,
#  'shows': 353,
#  'landline': 354,
#  'guys': 355,
#  'of': 356,
#  'po': 357,
#  'thanx': 358,
#  'dunno': 359,
#  'problem': 360,
#  'was': 361,
#  'office': 362,
#  'princess': 363,
#  'network': 364,
#  '000': 365,
#  'thank': 366,
#  'with': 367,
#  'maybe': 368,
#  'dis': 369,
#  'hear': 370,
#  'forgot': 371,
#  'sexy': 372,
#  'called': 373,
#  'asked': 374,
#  'hour': 375,
#  'shall': 376,
#  'probably': 377,
#  'from': 378,
#  'left': 379,
#  'dinner': 380,
#  "he's": 381,
#  '10': 382,
#  'afternoon': 383,
#  'bt': 384,
#  'mail': 385,
#  'without': 386,
#  'll': 387,
#  'working': 388,
#  'hav': 389,
#  'collect': 390,
#  'made': 391,
#  'put': 392,
#  'be': 393,
#  'kiss': 394,
#  'wife': 395,
#  'town': 396,
#  'goes': 397,
#  'fun': 398,
#  'selected': 399,
#  "there's": 400,
#  'calls': 401,
#  'pain': 402,
#  'part': 403,
#  'came': 404,
#  'okay': 405,
#  'worry': 406,
#  'juz': 407,
#  'must': 408,
#  'over': 409,
#  'join': 410,
#  'him': 411,
#  'decimal': 412,
#  'easy': 413,
#  'shopping': 414,
#  'plan': 415,
#  'baby': 416,
#  'plz': 417,
#  'tones': 418,
#  'texts': 419,
#  'den': 420,
#  '8': 421,
#  'bad': 422,
#  'enough': 423,
#  '2nd': 424,
#  'wanted': 425,
#  'weekend': 426,
#  'since': 427,
#  'won': 428,
#  'abt': 429,
#  'little': 430,
#  'coz': 431,
#  'xmas': 432,
#  'tmr': 433,
#  'evening': 434,
#  'everything': 435,
#  'didnt': 436,
#  'wake': 437,
#  'dude': 438,
#  'stay': 439,
#  'entry': 440,
#  '9': 441,
#  'code': 442,
#  'words': 443,
#  'alright': 444,
#  'bus': 445,
#  'till': 446,
#  "how's": 447,
#  'messages': 448,
#  'means': 449,
#  'movie': 450,
#  'says': 451,
#  'making': 452,
#  'award': 453,
#  'boy': 454,
#  'able': 455,
#  'leh': 456,
#  '500': 457,
#  "don't": 458,
#  'weekly': 459,
#  'lose': 460,
#  'fuck': 461,
#  'dad': 462,
#  'de': 463,
#  'gift': 464,
#  'though': 465,
#  'had': 466,
#  'å£100': 467,
#  'net': 468,
#  'times': 469,
#  'missed': 470,
#  'yesterday': 471,
#  'mob': 472,
#  'wen': 473,
#  'price': 474,
#  'food': 475,
#  'missing': 476,
#  'oso': 477,
#  '10p': 478,
#  'wot': 479,
#  'change': 480,
#  'wif': 481,
#  'question': 482,
#  'more': 483,
#  'update': 484,
#  'http': 485,
#  'national': 486,
#  "we're": 487,
#  'tomo': 488,
#  'saw': 489,
#  'double': 490,
#  'bonus': 491,
#  'comes': 492,
#  'run': 493,
#  'test': 494,
#  'address': 495,
#  "''": 496,
#  'answer': 497,
#  'top': 498,
#  'doing': 499,
#  'order': 500,
#  'til': 501,
#  'sleeping': 502,
#  "what's": 503,
#  'important': 504,
#  'true': 505,
#  'hot': 506,
#  'hurt': 507,
#  'book': 508,
#  'online': 509,
#  'pics': 510,
#  '8007': 511,
#  'plus': 512,
#  'valid': 513,
#  'ard': 514,
#  'took': 515,
#  'hair': 516,
#  'y': 517,
#  'anyway': 518,
#  'our': 519,
#  'vouchers': 520,
#  'music': 521,
#  'club': 522,
#  'any': 523,
#  'calling': 524,
#  'details': 525,
#  'either': 526,
#  'bored': 527,
#  'wants': 528,
#  'makes': 529,
#  'collection': 530,
#  'available': 531,
#  'set': 532,
#  'colour': 533,
#  'aft': 534,
#  'tried': 535,
#  'delivery': 536,
#  'who': 537,
#  'lucky': 538,
#  'finished': 539,
#  'close': 540,
#  'else': 541,
#  'mean': 542,
#  'busy': 543,
#  'school': 544,
#  'years': 545,
#  'everyone': 546,
#  'smoke': 547,
#  'awesome': 548,
#  'story': 549,
#  'noe': 550,
#  'g': 551,
#  'wid': 552,
#  '86688': 553,
#  'post': 554,
#  'chikku': 555,
#  'bring': 556,
#  'å£500': 557,
#  'beautiful': 558,
#  'feeling': 559,
#  'attempt': 560,
#  'guy': 561,
#  'sad': 562,
#  'lei': 563,
#  'final': 564,
#  'hours': 565,
#  'date': 566,
#  'ha': 567,
#  'å£5000': 568,
#  'show': 569,
#  'cause': 570,
#  'driving': 571,
#  'search': 572,
#  'todays': 573,
#  'haf': 574,
#  'lots': 575,
#  'should': 576,
#  'believe': 577,
#  'found': 578,
#  'id': 579,
#  'shop': 580,
#  'happen': 581,
#  'full': 582,
#  'friendship': 583,
#  "we'll": 584,
#  'row': 585,
#  'd': 586,
#  'whatever': 587,
#  'sch': 588,
#  'off': 589,
#  'family': 590,
#  'away': 591,
#  'goin': 592,
#  'drive': 593,
#  'pic': 594,
#  "c's": 595,
#  'pounds': 596,
#  'news': 597,
#  'forget': 598,
#  'congrats': 599,
#  'smiling': 600,
#  'havent': 601,
#  'after': 602,
#  'å£2000': 603,
#  'msgs': 604,
#  'services': 605,
#  'carlos': 606,
#  'worth': 607,
#  'gr8': 608,
#  'minute': 609,
#  'sis': 610,
#  'touch': 611,
#  'break': 612,
#  'walk': 613,
#  '750': 614,
#  'ring': 615,
#  'same': 616,
#  'charge': 617,
#  'okie': 618,
#  'w': 619,
#  'huh': 620,
#  'dating': 621,
#  'head': 622,
#  'land': 623,
#  'tot': 624,
#  'opt': 625,
#  'sae': 626,
#  'å£3': 627,
#  'sea': 628,
#  'fast': 629,
#  'together': 630,
#  'voucher': 631,
#  'email': 632,
#  '\x89û': 633,
#  'anyone': 634,
#  'drop': 635,
#  'brother': 636,
#  'treat': 637,
#  'winner': 638,
#  'second': 639,
#  'xx': 640,
#  'old': 641,
#  'quiz': 642,
#  'type': 643,
#  'whats': 644,
#  'ltd': 645,
#  'log': 646,
#  'college': 647,
#  'goodmorning': 648,
#  'oredi': 649,
#  'sounds': 650,
#  'angry': 651,
#  'unsubscribe': 652,
#  'choose': 653,
#  'blue': 654,
#  'far': 655,
#  'card': 656,
#  'sister': 657,
#  'mobileupd8': 658,
#  'bout': 659,
#  'eve': 660,
#  'gd': 661,
#  'savamob': 662,
#  'mum': 663,
#  'saying': 664,
#  'await': 665,
#  'dreams': 666,
#  'info': 667,
#  'pobox': 668,
#  'camcorder': 669,
#  '08000930705': 670,
#  'telling': 671,
#  'whole': 672,
#  'yours': 673,
#  'trip': 674,
#  'gone': 675,
#  '12hrs': 676,
#  'felt': 677,
#  'friday': 678,
#  'mu': 679,
#  'nt': 680,
#  'taking': 681,
#  'hard': 682,
#  'leaving': 683,
#  'parents': 684,
#  'needs': 685,
#  'm': 686,
#  'rs': 687,
#  'nite': 688,
#  'company': 689,
#  'secret': 690,
#  'thinks': 691,
#  'case': 692,
#  'meant': 693,
#  'face': 694,
#  'congratulations': 695,
#  'anytime': 696,
#  'unlimited': 697,
#  'lets': 698,
#  'games': 699,
#  'christmas': 700,
#  'light': 701,
#  'before': 702,
#  'suite342': 703,
#  '2lands': 704,
#  '08000839402': 705,
#  'poly': 706,
#  'pm': 707,
#  'ten': 708,
#  'kind': 709,
#  'thinking': 710,
#  'fri': 711,
#  'mine': 712,
#  'neva': 713,
#  'game': 714,
#  'pub': 715,
#  'them': 716,
#  'rite': 717,
#  'about': 718,
#  'lovely': 719,
#  'freemsg': 720,
#  "'": 721,
#  '100': 722,
#  'credit': 723,
#  'tho': 724,
#  'lesson': 725,
#  'seeing': 726,
#  'girls': 727,
#  'frnds': 728,
#  'gotta': 729,
#  'download': 730,
#  'prob': 731,
#  'hit': 732,
#  'operator': 733,
#  'points': 734,
#  'caller': 735,
#  '03': 736,
#  'player': 737,
#  'yr': 738,
#  'hand': 739,
#  'content': 740,
#  'wit': 741,
#  'bank': 742,
#  'mrng': 743,
#  'balance': 744,
#  'wil': 745,
#  'laptop': 746,
#  'tel': 747,
#  'dnt': 748,
#  'takes': 749,
#  'lost': 750,
#  'reading': 751,
#  'read': 752,
#  'currently': 753,
#  'ass': 754,
#  'drink': 755,
#  'fucking': 756,
#  'very': 757,
#  'cum': 758,
#  'outside': 759,
#  'listen': 760,
#  'snow': 761,
#  'area': 762,
#  'weeks': 763,
#  'sun': 764,
#  'b4': 765,
#  'wrong': 766,
#  'earlier': 767,
#  'loving': 768,
#  'party': 769,
#  'na': 770,
#  'chennai': 771,
#  'enter': 772,
#  'alone': 773,
#  'auction': 774,
#  'father': 775,
#  'point': 776,
#  'crazy': 777,
#  'press': 778,
#  'valued': 779,
#  '11': 780,
#  '20': 781,
#  'wonderful': 782,
#  'sunday': 783,
#  'eg': 784,
#  'hungry': 785,
#  'charged': 786,
#  'saturday': 787,
#  'abiola': 788,
#  'almost': 789,
#  'correct': 790,
#  'pass': 791,
#  'cut': 792,
#  'which': 793,
#  'hee': 794,
#  'does': 795,
#  'used': 796,
#  '0800': 797,
#  'mah': 798,
#  'happened': 799,
#  'entered': 800,
#  'askd': 801,
#  'private': 802,
#  'dogging': 803,
#  'direct': 804,
#  'age': 805,
#  'tired': 806,
#  'open': 807,
#  'fancy': 808,
#  'boytoy': 809,
#  'finally': 810,
#  'darlin': 811,
#  'march': 812,
#  'tc': 813,
#  'bcoz': 814,
#  'reveal': 815,
#  'fr': 816,
#  'questions': 817,
#  'down': 818,
#  'ends': 819,
#  'bslvyl': 820,
#  'txts': 821,
#  'ago': 822,
#  'motorola': 823,
#  'reason': 824,
#  'phones': 825,
#  'rock': 826,
#  'by': 827,
#  'å£250': 828,
#  'th': 829,
#  'welcome': 830,
#  'visit': 831,
#  'nope': 832,
#  'simple': 833,
#  'offers': 834,
#  'pretty': 835,
#  'o': 836,
#  'yar': 837,
#  'knw': 838,
#  'ans': 839,
#  'mates': 840,
#  'ugh': 841,
#  'heard': 842,
#  'information': 843,
#  'hows': 844,
#  'john': 845,
#  'nah': 846,
#  'callertune': 847,
#  'wap': 848,
#  'eh': 849,
#  'comin': 850,
#  'knows': 851,
#  'decided': 852,
#  'move': 853,
#  'song': 854,
#  'rply': 855,
#  'complimentary': 856,
#  'started': 857,
#  'loads': 858,
#  "b'day": 859,
#  'hmm': 860,
#  'sending': 861,
#  'frnd': 862,
#  'hmmm': 863,
#  'mr': 864,
#  'bath': 865,
#  '87066': 866,
#  'hold': 867,
#  'wana': 868,
#  'leaves': 869,
#  'hmv': 870,
#  'fone': 871,
#  'merry': 872,
#  'plans': 873,
#  'immediately': 874,
#  'jay': 875,
#  'met': 876,
#  'hg': 877,
#  'call2optout': 878,
#  'project': 879,
#  'couple': 880,
#  'mm': 881,
#  'india': 882,
#  'asking': 883,
#  'park': 884,
#  'less': 885,
#  'å£2': 886,
#  '00': 887,
#  'within': 888,
#  'hoping': 889,
#  'across': 890,
#  'happiness': 891,
#  'his': 892,
#  'ts': 893,
#  'sound': 894,
#  'paper': 895,
#  'once': 896,
#  'fantastic': 897,
#  'wonder': 898,
#  'picking': 899,
#  'mate': 900,
#  'understand': 901,
#  'ntt': 902,
#  'don': 903,
#  'truth': 904,
#  'feels': 905,
#  'surprise': 906,
#  'luck': 907,
#  'fact': 908,
#  'difficult': 909,
#  'empty': 910,
#  'wkly': 911,
#  'std': 912,
#  "i'd": 913,
#  'months': 914,
#  'mobiles': 915,
#  'smth': 916,
#  'worried': 917,
#  'sick': 918,
#  'confirm': 919,
#  'crave': 920,
#  'gets': 921,
#  'etc': 922,
#  'tickets': 923,
#  'il': 924,
#  'mom': 925,
#  'invited': 926,
#  'identifier': 927,
#  'expires': 928,
#  'numbers': 929,
#  'txting': 930,
#  'lect': 931,
#  'lovable': 932,
#  'safe': 933,
#  'f': 934,
#  'muz': 935,
#  'bathe': 936,
#  'side': 937,
#  'admirer': 938,
#  'lover': 939,
#  'disturb': 940,
#  'stupid': 941,
#  'die': 942,
#  'somebody': 943,
#  'somewhere': 944,
#  'accept': 945,
#  '2day': 946,
#  'normal': 947,
#  'rest': 948,
#  'via': 949,
#  'valentines': 950,
#  'w1j6hl': 951,
#  'st': 952,
#  'discount': 953,
#  'woke': 954,
#  'talking': 955,
#  'brings': 956,
#  'rental': 957,
#  'yep': 958,
#  'starts': 959,
#  'ldn': 960,
#  'kinda': 961,
#  'loan': 962,
#  'rent': 963,
#  'frm': 964,
#  'sub': 965,
#  'while': 966,
#  'blood': 967,
#  'warm': 968,
#  'cheap': 969,
#  'gym': 970,
#  'clean': 971,
#  'noon': 972,
#  'darren': 973,
#  'forwarded': 974,
#  'sex': 975,
#  'å£10': 976,
#  'store': 977,
#  'getzed': 978,
#  'gettin': 979,
#  'extra': 980,
#  'sort': 981,
#  'otherwise': 982,
#  "she's": 983,
#  'least': 984,
#  'nyt': 985,
#  'p': 986,
#  'loved': 987,
#  'police': 988,
#  'comp': 989,
#  'copy': 990,
#  'anymore': 991,
#  'promise': 992,
#  '87077': 993,
#  'catch': 994,
#  'replying': 995,
#  'decide': 996,
#  'wow': 997,
#  'ac': 998,
#  'red': 999,
#  'ice': 1000,
#  ...}

# %%
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels))
train_sequences = tokenizer.texts_to_sequences(train_articles)
train_padded = pad_sequences(train_sequences)

validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))
validation_sequences = tokenizer.texts_to_sequences(validation_articles)
validation_padded = pad_sequences(validation_sequences)

# %% [markdown]
# # **● Add Layers (LSTM, Dense-(Hidden Layers), Output)**

# %%
model = tf.keras.Sequential([
   
    tf.keras.layers.Embedding(5572, 64),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 64)          356608
#
#  bidirectional_3 (Bidirectio  (None, 64)               24832
#  nal)
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 383,718
# Trainable params: 383,718
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **● Compile the Model**

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # **● Fit the Model**

# %%
history = model.fit(train_padded, training_label_seq, epochs=15, validation_data=(validation_padded, validation_label_seq), verbose=2)
# Out:
# Epoch 1/15
# 140/140 - 10s - loss: 0.4353 - accuracy: 0.8981 - val_loss: 0.0660 - val_accuracy: 0.9848 - 10s/epoch - 68ms/step
# Epoch 2/15
# 140/140 - 6s - loss: 0.0364 - accuracy: 0.9904 - val_loss: 0.0650 - val_accuracy: 0.9830 - 6s/epoch - 42ms/step
# Epoch 3/15
# 140/140 - 6s - loss: 0.0118 - accuracy: 0.9982 - val_loss: 0.0361 - val_accuracy: 0.9901 - 6s/epoch - 42ms/step
# Epoch 4/15
# 140/140 - 6s - loss: 0.0054 - accuracy: 0.9991 - val_loss: 0.0390 - val_accuracy: 0.9901 - 6s/epoch - 42ms/step
# Epoch 5/15
# 140/140 - 6s - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0448 - val_accuracy: 0.9892 - 6s/epoch - 43ms/step
# Epoch 6/15
# 140/140 - 6s - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.0507 - val_accuracy: 0.9874 - 6s/epoch - 42ms/step
# Epoch 7/15
# 140/140 - 6s - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.0552 - val_accuracy: 0.9892 - 6s/epoch - 42ms/step
# Epoch 8/15
# 140/140 - 6s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0521 - val_accuracy: 0.9874 - 6s/epoch - 42ms/step
# Epoch 9/15
# 140/140 - 6s - loss: 5.6748e-04 - accuracy: 0.9998 - val_loss: 0.0535 - val_accuracy: 0.9848 - 6s/epoch - 42ms/step
# Epoch 10/15
# 140/140 - 6s - loss: 2.5135e-04 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9901 - 6s/epoch - 42ms/step
# Epoch 11/15
# 140/140 - 6s - loss: 1.5996e-04 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9901 - 6s/epoch - 42ms/step
# Epoch 12/15
# 140/140 - 6s - loss: 1.1766e-04 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9901 - 6s/epoch - 42ms/step
# Epoch 13/15
# 140/140 - 6s - loss: 8.9408e-05 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9892 - 6s/epoch - 42ms/step
# Epoch 14/15
# 140/140 - 6s - loss: 7.7864e-05 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9901 - 6s/epoch - 42ms/step
# Epoch 15/15
# 140/140 - 6s - loss: 6.1367e-05 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9901 - 6s/epoch - 42ms/step

# %% [markdown]
# # **● Save The Model**

# %%
model.save("spam.h1")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses, lstm_cell_17_layer_call_fn, lstm_cell_17_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %% [markdown]
# # **● Test The Model**

# %%
from tensorflow.keras.models import load_model
model = load_model("/content/spam.h1")

# %% [markdown]
# # Test 1

# %%
test = ["Nah I don't think he goes to usf, he lives around here though	"]

seq = tokenizer.texts_to_sequences(test)
paddedSeq = pad_sequences(seq)
predicted_class = model.predict(paddedSeq)
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
labels = ['Not spam','Likely Not spam','Spam','Likely Spam','Cannot be determined']
labels[np.argmax(predicted_class)]
# Out:
# 'Likely Not spam'

# %% [markdown]
# # Test 2

# %%
test = ["Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with camera for Free! Call The Mobile Update Co FREE on 08002986030"]

seq = tokenizer.texts_to_sequences(test)
paddedSeq = pad_sequences(seq)
predicted_class = model.predict(paddedSeq)
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %%
labels[np.argmax(predicted_class)]
# Out:
# 'Spam'

# %% [markdown]
# # Test 3

# %%
test = ["URGENT! You have won a 1 week FREE membership in our å£100,000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18"]

seq = tokenizer.texts_to_sequences(test)
paddedSeq = pad_sequences(seq)
predicted_class = model.predict(paddedSeq)
# Out:
# 1/1 [==============================] - 0s 14ms/step

# %%
labels[np.argmax(predicted_class)]
# Out:
# 'Spam'
